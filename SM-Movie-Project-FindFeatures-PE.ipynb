# %% [markdown]
# # Initialize

# %% [markdown]
# ## ASW session

# %%
import boto3

session = boto3.Session()
s3 = session.resource('s3')

# %% [markdown]
# ## SageMaker Session

# %%
import sagemaker

sage_session = sagemaker.Session()

# %% [markdown]
# # Define Globals

# %%
# bucket name
bucket = 'aida-project'

# path for s3_input
s3_path = f"s3://{bucket}/"

## define source files
# TRAIN source file
train_source_path = 'team_remote'
train_source_name = 'title-train.csv'
#train_source_name = 'title-valid.csv'       # for testing; remove later


# VALID source file
valid_source_path = 'team_remote'
valid_source_name = 'title-valid.csv'
#valid_source_name = 'title-test.csv'       # for testing; remove later

# TEST source file
test_source_path = 'team_remote'
test_source_name = 'title-test.csv'

# output for result
output_path ='team_remote'
output_location = f'{s3_path}{output_path}/output'

# %%
print(output_location)
# Out:
# s3://aida-project/team_remote/output

# %%
# Create pointers to the S3 train and test datasets

from sagemaker import s3_input

# print(f"{s3_path}{train_source_path}/{train_source_name}")
# print(f"{s3_path}{valid_source_path}/{valid_source_name}")
# print(f"{s3_path}{test_source_path}/{test_source_name}")
s3_input_train = sagemaker.session.s3_input(s3_data=f"{s3_path}{train_source_path}/{train_source_name}", content_type="text/csv")
s3_input_valid = sagemaker.session.s3_input(s3_data=f"{s3_path}{valid_source_path}/{valid_source_name}", content_type="text/csv")
s3_input_test = sagemaker.session.s3_input(s3_data=f"{s3_path}{test_source_path}/{test_source_name}", content_type="text/csv")
# Out:
# 's3_input' class will be renamed to 'TrainingInput' in SageMaker Python SDK v2.
# 's3_input' class will be renamed to 'TrainingInput' in SageMaker Python SDK v2.
# 's3_input' class will be renamed to 'TrainingInput' in SageMaker Python SDK v2.

# %%
role = sagemaker.get_execution_role()

# %% [markdown]
# # Define Model

# %%
# finde pre-defined models here:
# https://docs.aws.amazon.com/sagemaker/latest/dg/sagemaker-algo-docker-registry-paths.html

# Create an XGBoost Estimator

# estimator call
# <ecr_path>/sagemaker-xgboost:1.2-1
    
ecr_path = "492215442770.dkr.ecr.eu-central-1.amazonaws.com"
xgboost_estimator = f"{ecr_path}/sagemaker-xgboost:1.0-1-cpu-py3"

# ecr_path = "664544806723.dkr.ecr.eu-central-1.amazonaws.com"
# knn_estimator = f"{ecr_path}/knn:latest"

# %%
xgboost = sagemaker.estimator.Estimator(xgboost_estimator,
                              role,
                              train_instance_count=1,
                              train_instance_type="ml.m5.4xlarge",
                              output_path=output_location,
                              sagemaker_session=sage_session,
                              base_job_name="JPC-xgboost")
# Out:
# Parameter image_name will be renamed to image_uri in SageMaker Python SDK v2.

# %%
# Select the your specific hyperparameters (Optional)
# https://docs.aws.amazon.com/sagemaker/latest/dg/xgboost_hyperparameters.html
# https://github.com/dmlc/xgboost/blob/master/doc/parameter.rst#learning-task-parameters 

xgboost.set_hyperparameters(
    eta=.35,
    num_round=252,                     # required parameter!
    objective = 'reg:linear',
    )

# %%
from sagemaker.debugger import rule_configs, Rule, DebuggerHookConfig, CollectionConfig
from sagemaker.estimator import Estimator 
save_interval = 50
xgboost_debugger = Estimator( role=role, 
                             base_job_name="JPC-xgboost-debug", 
                             train_instance_count=1, 
                             train_instance_type='ml.m5.4xlarge', 
                             image_name=xgboost_estimator, 
                             #hyperparameters=hyperparameters, 
                             train_max_run=1800, 
                             debugger_hook_config=DebuggerHookConfig( s3_output_path=output_location, # Required 
                             collection_configs=[ CollectionConfig( name="feature_importance", parameters={ "save_interval": str(save_interval) } ), ], ), 
                              rules=[ Rule.sagemaker( rule_configs.loss_not_decreasing(), 
                                                     rule_parameters={ "collection_names": "metrics", "num_steps": str(save_interval * 2), }, ), ],
)
xgboost_debugger.set_hyperparameters(
    eta=.5,
    # gamma=0.5,
    alpha = 0.55,
    #lambda_bias=0.4,
    num_round=352                     # required parameter!
    #objective = 'reg:linear',
    )
# Out:
# Parameter image_name will be renamed to image_uri in SageMaker Python SDK v2.

# %% [markdown]
# ## Fit Model

# %%
xgboost_debugger.fit({"train": s3_input_train, "validation": s3_input_valid}, wait=True)
# Out:
# 2020-11-19 20:42:35 Starting - Starting the training job...
# 2020-11-19 20:42:59 Starting - Launching requested ML instances
# ********* Debugger Rule Status *********
# *
# *  LossNotDecreasing: InProgress
# *
# ****************************************
# ......
# 2020-11-19 20:44:00 Starting - Preparing the instances for training...
# 2020-11-19 20:44:25 Downloading - Downloading input data...
# 2020-11-19 20:45:00 Training - Training image download completed. Training in progress..INFO:sagemaker-containers:Imported framework sagemaker_xgboost_container.training
# INFO:sagemaker-containers:No GPUs detected (normal if no gpus installed)
# INFO:sagemaker_xgboost_container.training:Running XGBoost Sagemaker in algorithm mode
# INFO:root:Determined delimiter of CSV input is ','
# INFO:root:Determined delimiter of CSV input is ','
# INFO:root:Determined delimiter of CSV input is ','
# [20:45:01] 804602x44 matrix with 35402488 entries loaded from /opt/ml/input/data/train?format=csv&label_column=0&delimiter=,
# INFO:root:Determined delimiter of CSV input is ','
# [20:45:02] 89652x44 matrix with 3944688 entries loaded from /opt/ml/input/data/validation?format=csv&label_column=0&delimiter=,
# INFO:root:Single node training.
# [2020-11-19 20:45:02.167 ip-10-0-220-184.eu-central-1.compute.internal:1 INFO json_config.py:90] Creating hook from json_config at /opt/ml/input/config/debughookconfig.json.
# [2020-11-19 20:45:02.167 ip-10-0-220-184.eu-central-1.compute.internal:1 INFO hook.py:151] tensorboard_dir has not been set for the hook. SMDebug will not be exporting tensorboard summaries.
# [2020-11-19 20:45:02.168 ip-10-0-220-184.eu-central-1.compute.internal:1 INFO hook.py:196] Saving to /opt/ml/output/tensors
# INFO:root:Debug hook created from config
# INFO:root:Train matrix has 804602 rows
# INFO:root:Validation matrix has 89652 rows
# [20:45:02] WARNING: /workspace/src/learner.cc:328:
# Parameters: { num_round } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [0]#011train-rmse:3.44126#011validation-rmse:3.43495
# [2020-11-19 20:45:02.766 ip-10-0-220-184.eu-central-1.compute.internal:1 INFO hook.py:325] Monitoring the collections: metrics, losses, feature_importance
# [1]#011train-rmse:2.02213#011validation-rmse:2.01607
# [2]#011train-rmse:1.46055#011validation-rmse:1.45482
# [3]#011train-rmse:1.27308#011validation-rmse:1.26693
# [4]#011train-rmse:1.22070#011validation-rmse:1.21513
# [5]#011train-rmse:1.20386#011validation-rmse:1.19842
# [6]#011train-rmse:1.19754#011validation-rmse:1.19221
# [7]#011train-rmse:1.19308#011validation-rmse:1.18777
# [8]#011train-rmse:1.19025#011validation-rmse:1.18526
# [9]#011train-rmse:1.18452#011validation-rmse:1.18005
# [10]#011train-rmse:1.18234#011validation-rmse:1.17784
# [11]#011train-rmse:1.17877#011validation-rmse:1.17445
# [12]#011train-rmse:1.17709#011validation-rmse:1.17316
# [13]#011train-rmse:1.17539#011validation-rmse:1.17162
# [14]#011train-rmse:1.17269#011validation-rmse:1.16896
# [15]#011train-rmse:1.17145#011validation-rmse:1.16780
# [16]#011train-rmse:1.17006#011validation-rmse:1.16672
# [17]#011train-rmse:1.16912#011validation-rmse:1.16587
# [18]#011train-rmse:1.16798#011validation-rmse:1.16478
# [19]#011train-rmse:1.16665#011validation-rmse:1.16357
# [20]#011train-rmse:1.16582#011validation-rmse:1.16294
# [21]#011train-rmse:1.16462#011validation-rmse:1.16190
# [22]#011train-rmse:1.16400#011validation-rmse:1.16144
# [23]#011train-rmse:1.16194#011validation-rmse:1.15920
# [24]#011train-rmse:1.16040#011validation-rmse:1.15786
# [25]#011train-rmse:1.15993#011validation-rmse:1.15752
# [26]#011train-rmse:1.15911#011validation-rmse:1.15675
# [27]#011train-rmse:1.15817#011validation-rmse:1.15595
# [28]#011train-rmse:1.15720#011validation-rmse:1.15503
# [29]#011train-rmse:1.15665#011validation-rmse:1.15458
# [30]#011train-rmse:1.15559#011validation-rmse:1.15364
# [31]#011train-rmse:1.15540#011validation-rmse:1.15346
# [32]#011train-rmse:1.15446#011validation-rmse:1.15255
# [33]#011train-rmse:1.15285#011validation-rmse:1.15135
# [34]#011train-rmse:1.15182#011validation-rmse:1.15044
# [35]#011train-rmse:1.15097#011validation-rmse:1.14964
# [36]#011train-rmse:1.15042#011validation-rmse:1.14938
# [37]#011train-rmse:1.14980#011validation-rmse:1.14899
# [38]#011train-rmse:1.14967#011validation-rmse:1.14893
# [39]#011train-rmse:1.14840#011validation-rmse:1.14794
# [40]#011train-rmse:1.14783#011validation-rmse:1.14738
# [41]#011train-rmse:1.14730#011validation-rmse:1.14695
# [42]#011train-rmse:1.14712#011validation-rmse:1.14686
# [43]#011train-rmse:1.14679#011validation-rmse:1.14657
# [44]#011train-rmse:1.14574#011validation-rmse:1.14575
# [45]#011train-rmse:1.14478#011validation-rmse:1.14487
# [46]#011train-rmse:1.14438#011validation-rmse:1.14466
# [47]#011train-rmse:1.14386#011validation-rmse:1.14422
# [48]#011train-rmse:1.14326#011validation-rmse:1.14376
# [49]#011train-rmse:1.14262#011validation-rmse:1.14328
# [50]#011train-rmse:1.14252#011validation-rmse:1.14322
# [51]#011train-rmse:1.14233#011validation-rmse:1.14312
# [52]#011train-rmse:1.14150#011validation-rmse:1.14223
# [53]#011train-rmse:1.14101#011validation-rmse:1.14202
# [54]#011train-rmse:1.14030#011validation-rmse:1.14144
# [55]#011train-rmse:1.13960#011validation-rmse:1.14078
# [56]#011train-rmse:1.13950#011validation-rmse:1.14072
# [57]#011train-rmse:1.13929#011validation-rmse:1.14059
# [58]#011train-rmse:1.13921#011validation-rmse:1.14056
# [59]#011train-rmse:1.13852#011validation-rmse:1.14019
# [60]#011train-rmse:1.13810#011validation-rmse:1.13987
# [61]#011train-rmse:1.13765#011validation-rmse:1.13953
# [62]#011train-rmse:1.13721#011validation-rmse:1.13914
# [63]#011train-rmse:1.13648#011validation-rmse:1.13850
# [64]#011train-rmse:1.13597#011validation-rmse:1.13809
# [65]#011train-rmse:1.13572#011validation-rmse:1.13789
# [66]#011train-rmse:1.13531#011validation-rmse:1.13767
# [67]#011train-rmse:1.13514#011validation-rmse:1.13764
# [68]#011train-rmse:1.13479#011validation-rmse:1.13731
# [69]#011train-rmse:1.13445#011validation-rmse:1.13712
# [70]#011train-rmse:1.13421#011validation-rmse:1.13700
# [71]#011train-rmse:1.13388#011validation-rmse:1.13676
# [72]#011train-rmse:1.13348#011validation-rmse:1.13644
# [73]#011train-rmse:1.13315#011validation-rmse:1.13627
# [74]#011train-rmse:1.13310#011validation-rmse:1.13627
# [75]#011train-rmse:1.13272#011validation-rmse:1.13610
# [76]#011train-rmse:1.13216#011validation-rmse:1.13568
# [77]#011train-rmse:1.13196#011validation-rmse:1.13570
# [78]#011train-rmse:1.13172#011validation-rmse:1.13555
# [79]#011train-rmse:1.13165#011validation-rmse:1.13549
# [80]#011train-rmse:1.13115#011validation-rmse:1.13520
# [81]#011train-rmse:1.13066#011validation-rmse:1.13485
# [82]#011train-rmse:1.13040#011validation-rmse:1.13465
# [83]#011train-rmse:1.13019#011validation-rmse:1.13455
# [84]#011train-rmse:1.13004#011validation-rmse:1.13450
# [85]#011train-rmse:1.12973#011validation-rmse:1.13431
# [86]#011train-rmse:1.12945#011validation-rmse:1.13427
# [87]#011train-rmse:1.12940#011validation-rmse:1.13427
# [88]#011train-rmse:1.12931#011validation-rmse:1.13422
# [89]#011train-rmse:1.12902#011validation-rmse:1.13410
# [90]#011train-rmse:1.12877#011validation-rmse:1.13385
# [91]#011train-rmse:1.12846#011validation-rmse:1.13363
# [92]#011train-rmse:1.12837#011validation-rmse:1.13360
# [93]#011train-rmse:1.12829#011validation-rmse:1.13353
# [94]#011train-rmse:1.12812#011validation-rmse:1.13338
# [95]#011train-rmse:1.12767#011validation-rmse:1.13294
# [96]#011train-rmse:1.12733#011validation-rmse:1.13279
# [97]#011train-rmse:1.12694#011validation-rmse:1.13252
# [98]#011train-rmse:1.12675#011validation-rmse:1.13242
# [99]#011train-rmse:1.12642#011validation-rmse:1.13206
# [100]#011train-rmse:1.12601#011validation-rmse:1.13180
# [101]#011train-rmse:1.12577#011validation-rmse:1.13159
# [102]#011train-rmse:1.12525#011validation-rmse:1.13107
# [103]#011train-rmse:1.12506#011validation-rmse:1.13088
# [104]#011train-rmse:1.12469#011validation-rmse:1.13064
# [105]#011train-rmse:1.12457#011validation-rmse:1.13062
# [106]#011train-rmse:1.12429#011validation-rmse:1.13050
# [107]#011train-rmse:1.12421#011validation-rmse:1.13047
# [108]#011train-rmse:1.12386#011validation-rmse:1.13020
# [109]#011train-rmse:1.12341#011validation-rmse:1.12981
# [110]#011train-rmse:1.12329#011validation-rmse:1.12981
# [111]#011train-rmse:1.12272#011validation-rmse:1.12944
# [112]#011train-rmse:1.12236#011validation-rmse:1.12914
# [113]#011train-rmse:1.12223#011validation-rmse:1.12906
# [114]#011train-rmse:1.12201#011validation-rmse:1.12896
# [115]#011train-rmse:1.12180#011validation-rmse:1.12886
# [116]#011train-rmse:1.12149#011validation-rmse:1.12868
# [117]#011train-rmse:1.12130#011validation-rmse:1.12854
# [118]#011train-rmse:1.12111#011validation-rmse:1.12842
# [119]#011train-rmse:1.12062#011validation-rmse:1.12801
# [120]#011train-rmse:1.12036#011validation-rmse:1.12785
# [121]#011train-rmse:1.11990#011validation-rmse:1.12757
# [122]#011train-rmse:1.11970#011validation-rmse:1.12747
# [123]#011train-rmse:1.11946#011validation-rmse:1.12725
# [124]#011train-rmse:1.11920#011validation-rmse:1.12708
# [125]#011train-rmse:1.11917#011validation-rmse:1.12708
# [126]#011train-rmse:1.11866#011validation-rmse:1.12669
# [127]#011train-rmse:1.11831#011validation-rmse:1.12654
# [128]#011train-rmse:1.11808#011validation-rmse:1.12638
# [129]#011train-rmse:1.11797#011validation-rmse:1.12634
# [130]#011train-rmse:1.11779#011validation-rmse:1.12622
# [131]#011train-rmse:1.11760#011validation-rmse:1.12612
# [132]#011train-rmse:1.11733#011validation-rmse:1.12595
# [133]#011train-rmse:1.11703#011validation-rmse:1.12572
# [134]#011train-rmse:1.11675#011validation-rmse:1.12563
# [135]#011train-rmse:1.11647#011validation-rmse:1.12549
# [136]#011train-rmse:1.11630#011validation-rmse:1.12536
# [137]#011train-rmse:1.11617#011validation-rmse:1.12525
# [138]#011train-rmse:1.11610#011validation-rmse:1.12516
# [139]#011train-rmse:1.11597#011validation-rmse:1.12504
# [140]#011train-rmse:1.11563#011validation-rmse:1.12478
# [141]#011train-rmse:1.11540#011validation-rmse:1.12467
# [142]#011train-rmse:1.11512#011validation-rmse:1.12441
# [143]#011train-rmse:1.11499#011validation-rmse:1.12434
# [144]#011train-rmse:1.11481#011validation-rmse:1.12429
# [145]#011train-rmse:1.11467#011validation-rmse:1.12430
# [146]#011train-rmse:1.11457#011validation-rmse:1.12425
# [147]#011train-rmse:1.11443#011validation-rmse:1.12423
# [148]#011train-rmse:1.11439#011validation-rmse:1.12424
# [149]#011train-rmse:1.11422#011validation-rmse:1.12418
# [150]#011train-rmse:1.11403#011validation-rmse:1.12414
# [151]#011train-rmse:1.11382#011validation-rmse:1.12396
# [152]#011train-rmse:1.11375#011validation-rmse:1.12393
# [153]#011train-rmse:1.11367#011validation-rmse:1.12389
# [154]#011train-rmse:1.11354#011validation-rmse:1.12391
# [155]#011train-rmse:1.11345#011validation-rmse:1.12397
# [156]#011train-rmse:1.11325#011validation-rmse:1.12387
# [157]#011train-rmse:1.11302#011validation-rmse:1.12374
# [158]#011train-rmse:1.11290#011validation-rmse:1.12371
# [159]#011train-rmse:1.11261#011validation-rmse:1.12363
# [160]#011train-rmse:1.11248#011validation-rmse:1.12359
# [161]#011train-rmse:1.11214#011validation-rmse:1.12333
# [162]#011train-rmse:1.11181#011validation-rmse:1.12306
# [163]#011train-rmse:1.11163#011validation-rmse:1.12296
# [164]#011train-rmse:1.11138#011validation-rmse:1.12272
# [165]#011train-rmse:1.11123#011validation-rmse:1.12268
# [166]#011train-rmse:1.11108#011validation-rmse:1.12265
# [167]#011train-rmse:1.11091#011validation-rmse:1.12253
# [168]#011train-rmse:1.11080#011validation-rmse:1.12254
# [169]#011train-rmse:1.11059#011validation-rmse:1.12252
# [170]#011train-rmse:1.11038#011validation-rmse:1.12252
# [171]#011train-rmse:1.11022#011validation-rmse:1.12242
# [172]#011train-rmse:1.11000#011validation-rmse:1.12224
# [173]#011train-rmse:1.10980#011validation-rmse:1.12217
# [174]#011train-rmse:1.10956#011validation-rmse:1.12197
# [175]#011train-rmse:1.10950#011validation-rmse:1.12194
# [176]#011train-rmse:1.10936#011validation-rmse:1.12190
# [177]#011train-rmse:1.10919#011validation-rmse:1.12184
# [178]#011train-rmse:1.10910#011validation-rmse:1.12187
# [179]#011train-rmse:1.10899#011validation-rmse:1.12180
# [180]#011train-rmse:1.10893#011validation-rmse:1.12180
# [181]#011train-rmse:1.10872#011validation-rmse:1.12180
# [182]#011train-rmse:1.10871#011validation-rmse:1.12180
# [183]#011train-rmse:1.10847#011validation-rmse:1.12164
# [184]#011train-rmse:1.10838#011validation-rmse:1.12168
# [185]#011train-rmse:1.10829#011validation-rmse:1.12168
# [186]#011train-rmse:1.10820#011validation-rmse:1.12168
# [187]#011train-rmse:1.10813#011validation-rmse:1.12168
# [188]#011train-rmse:1.10798#011validation-rmse:1.12163
# [189]#011train-rmse:1.10791#011validation-rmse:1.12163
# [190]#011train-rmse:1.10789#011validation-rmse:1.12162
# [191]#011train-rmse:1.10777#011validation-rmse:1.12154
# [192]#011train-rmse:1.10763#011validation-rmse:1.12147
# [193]#011train-rmse:1.10759#011validation-rmse:1.12147
# [194]#011train-rmse:1.10751#011validation-rmse:1.12149
# [195]#011train-rmse:1.10741#011validation-rmse:1.12151
# [196]#011train-rmse:1.10733#011validation-rmse:1.12149
# [197]#011train-rmse:1.10716#011validation-rmse:1.12151
# [198]#011train-rmse:1.10707#011validation-rmse:1.12154
# [199]#011train-rmse:1.10700#011validation-rmse:1.12156
# [200]#011train-rmse:1.10699#011validation-rmse:1.12156
# [201]#011train-rmse:1.10670#011validation-rmse:1.12138
# [202]#011train-rmse:1.10642#011validation-rmse:1.12115
# [203]#011train-rmse:1.10637#011validation-rmse:1.12114
# [204]#011train-rmse:1.10629#011validation-rmse:1.12111
# [205]#011train-rmse:1.10606#011validation-rmse:1.12104
# [206]#011train-rmse:1.10604#011validation-rmse:1.12103
# [207]#011train-rmse:1.10596#011validation-rmse:1.12102
# [208]#011train-rmse:1.10578#011validation-rmse:1.12095
# [209]#011train-rmse:1.10575#011validation-rmse:1.12092
# [210]#011train-rmse:1.10545#011validation-rmse:1.12079
# [211]#011train-rmse:1.10533#011validation-rmse:1.12076
# [212]#011train-rmse:1.10498#011validation-rmse:1.12046
# [213]#011train-rmse:1.10477#011validation-rmse:1.12047
# [214]#011train-rmse:1.10460#011validation-rmse:1.12035
# [215]#011train-rmse:1.10445#011validation-rmse:1.12035
# [216]#011train-rmse:1.10425#011validation-rmse:1.12031
# [217]#011train-rmse:1.10411#011validation-rmse:1.12019
# [218]#011train-rmse:1.10406#011validation-rmse:1.12018
# [219]#011train-rmse:1.10394#011validation-rmse:1.12014
# [220]#011train-rmse:1.10379#011validation-rmse:1.12010
# [221]#011train-rmse:1.10373#011validation-rmse:1.12011
# [222]#011train-rmse:1.10369#011validation-rmse:1.12011
# [223]#011train-rmse:1.10358#011validation-rmse:1.12005
# [224]#011train-rmse:1.10345#011validation-rmse:1.12002
# [225]#011train-rmse:1.10339#011validation-rmse:1.12002
# [226]#011train-rmse:1.10333#011validation-rmse:1.12001
# [227]#011train-rmse:1.10323#011validation-rmse:1.11999
# [228]#011train-rmse:1.10296#011validation-rmse:1.11982
# [229]#011train-rmse:1.10289#011validation-rmse:1.11979
# [230]#011train-rmse:1.10282#011validation-rmse:1.11978
# [231]#011train-rmse:1.10268#011validation-rmse:1.11974
# [232]#011train-rmse:1.10247#011validation-rmse:1.11960
# [233]#011train-rmse:1.10234#011validation-rmse:1.11950
# [234]#011train-rmse:1.10226#011validation-rmse:1.11953
# [235]#011train-rmse:1.10217#011validation-rmse:1.11947
# [236]#011train-rmse:1.10201#011validation-rmse:1.11945
# [237]#011train-rmse:1.10172#011validation-rmse:1.11931
# [238]#011train-rmse:1.10159#011validation-rmse:1.11923
# [239]#011train-rmse:1.10149#011validation-rmse:1.11922
# [240]#011train-rmse:1.10130#011validation-rmse:1.11916
# [241]#011train-rmse:1.10113#011validation-rmse:1.11909
# [242]#011train-rmse:1.10097#011validation-rmse:1.11903
# [243]#011train-rmse:1.10080#011validation-rmse:1.11895
# [244]#011train-rmse:1.10063#011validation-rmse:1.11892
# [245]#011train-rmse:1.10042#011validation-rmse:1.11884
# [246]#011train-rmse:1.10024#011validation-rmse:1.11881
# [247]#011train-rmse:1.10012#011validation-rmse:1.11882
# [248]#011train-rmse:1.10009#011validation-rmse:1.11883
# [249]#011train-rmse:1.09983#011validation-rmse:1.11868
# [250]#011train-rmse:1.09971#011validation-rmse:1.11864
# [251]#011train-rmse:1.09962#011validation-rmse:1.11860
# [252]#011train-rmse:1.09957#011validation-rmse:1.11857
# [253]#011train-rmse:1.09950#011validation-rmse:1.11852
# [254]#011train-rmse:1.09936#011validation-rmse:1.11850
# [255]#011train-rmse:1.09931#011validation-rmse:1.11851
# [256]#011train-rmse:1.09913#011validation-rmse:1.11854
# [257]#011train-rmse:1.09898#011validation-rmse:1.11851
# [258]#011train-rmse:1.09892#011validation-rmse:1.11851
# [259]#011train-rmse:1.09888#011validation-rmse:1.11850
# [260]#011train-rmse:1.09872#011validation-rmse:1.11840
# [261]#011train-rmse:1.09863#011validation-rmse:1.11844
# [262]#011train-rmse:1.09860#011validation-rmse:1.11845
# [263]#011train-rmse:1.09858#011validation-rmse:1.11845
# [264]#011train-rmse:1.09856#011validation-rmse:1.11845
# [265]#011train-rmse:1.09827#011validation-rmse:1.11842
# [266]#011train-rmse:1.09816#011validation-rmse:1.11843
# [267]#011train-rmse:1.09807#011validation-rmse:1.11843
# [268]#011train-rmse:1.09797#011validation-rmse:1.11837
# [319]#011train-rmse:1.09280#011validation-rmse:1.11675
# [320]#011train-rmse:1.09267#011validation-rmse:1.11670
# [321]#011train-rmse:1.09256#011validation-rmse:1.11665
# [322]#011train-rmse:1.09241#011validation-rmse:1.11650
# [323]#011train-rmse:1.09226#011validation-rmse:1.11644
# [324]#011train-rmse:1.09208#011validation-rmse:1.11630
# [325]#011train-rmse:1.09198#011validation-rmse:1.11623
# [326]#011train-rmse:1.09186#011validation-rmse:1.11616
# [327]#011train-rmse:1.09179#011validation-rmse:1.11614
# [328]#011train-rmse:1.09159#011validation-rmse:1.11601
# [329]#011train-rmse:1.09151#011validation-rmse:1.11602
# [330]#011train-rmse:1.09148#011validation-rmse:1.11604
# [331]#011train-rmse:1.09143#011validation-rmse:1.11603
# [332]#011train-rmse:1.09136#011validation-rmse:1.11603
# [333]#011train-rmse:1.09115#011validation-rmse:1.11593
# [334]#011train-rmse:1.09101#011validation-rmse:1.11581
# [335]#011train-rmse:1.09090#011validation-rmse:1.11577
# [336]#011train-rmse:1.09069#011validation-rmse:1.11566
# [337]#011train-rmse:1.09060#011validation-rmse:1.11565
# [338]#011train-rmse:1.09047#011validation-rmse:1.11563
# [339]#011train-rmse:1.09026#011validation-rmse:1.11556
# [340]#011train-rmse:1.09012#011validation-rmse:1.11550
# [341]#011train-rmse:1.08997#011validation-rmse:1.11543
# [342]#011train-rmse:1.08986#011validation-rmse:1.11539
# [343]#011train-rmse:1.08973#011validation-rmse:1.11540
# [344]#011train-rmse:1.08963#011validation-rmse:1.11538
# [345]#011train-rmse:1.08952#011validation-rmse:1.11540
# [346]#011train-rmse:1.08946#011validation-rmse:1.11541
#
# 2020-11-19 20:46:33 Uploading - Uploading generated training model
# 2020-11-19 20:46:33 Completed - Training job completed
# [347]#011train-rmse:1.08937#011validation-rmse:1.11540
# [348]#011train-rmse:1.08933#011validation-rmse:1.11538
# [349]#011train-rmse:1.08924#011validation-rmse:1.11542
# [350]#011train-rmse:1.08910#011validation-rmse:1.11536
# [351]#011train-rmse:1.08905#011validation-rmse:1.11538
# Training seconds: 128
# Billable seconds: 128

# %% [markdown]
# 352 runden:
# eta 0-35
# alpha 0.3: 1.09971 1.11727
# alpha 0.4: 1.09879 1.11689
# alpha 0.5: 1.09976 1.11694
# alpha 0.6: 1.10047 1.11785
#
# alpha 0.4
# eta 0.35: 1.09879 1.11689
# eta 0.40: 1.09578 1.11635
#
# eta 0.4
# alpha 0.45: 1.09548 1.11630
# alpha 0.50: 1.09582 1.11585
# alpha 0.55: 1.09560 1.11577
#
# eta 0.45 alpha 0.55: 1.09178 1.11506
# eta 0.50 alpha 0.55: 1.08905 1.11538

# %%
#!pip install smdebug
from smdebug.trials import create_trial
s3_output_path = xgboost_debugger.latest_job_debugger_artifacts_path()
trial = create_trial(s3_output_path)
liste = trial.tensor_names()
feature_importance_names = [k for k in liste if 'feature_importance/cover' in k]
feature_importance_col_names = ['isAdult', 'startYear', 'endYear', 'numVotes', 'Crime', 'Romance', 'Thriller', 'Adventure', 'Drama', 'War', 'Documentary', 'Reality-TV', 'Family', 'Fantasy', 'Game-Show', 'Adult', 'History', 'Mystery', 'Musical', 'Animation', 'Music', 'Film-Noir', 'shortGenre', 'Horror', 'Western', 'Biography', 'Comedy', 'Action', 'Sport', 'Talk-Show', 'Sci-Fi', 'News', 'movie', 'short', 'tvEpisode', 'tvMiniSeries', 'tvMovie', 'tvSeries', 'tvShort', 'tvSpecial', 'video', 'videoGame', 'distinct languages', 'distinct regions']
# Out:
# [2020-11-19 20:53:10.980 ip-172-16-29-248:6872 INFO s3_trial.py:42] Loading trial debug-output at path s3://aida-project/team_remote/output/JPC-xgboost-debug-2020-11-19-20-42-34-913/debug-output
# [2020-11-19 20:53:12.066 ip-172-16-29-248:6872 INFO trial.py:198] Training has ended, will refresh one final time in 1 sec.
# [2020-11-19 20:53:13.085 ip-172-16-29-248:6872 INFO trial.py:210] Loaded all steps

# %%
# change of feature weight over time
feat_dict_step={}
feat_dict_step={}
start=50
step = 50
ende=350
for i,f in enumerate(feature_importance_names):
    tmp=[]
    index=int(f.split('f')[2])
    lbl=feature_importance_col_names[index]
    #print(trial.tensor(f).values())
    for j in range(start, ende+1,step):
        try:
            tmp.append(trial.tensor(f).values()[j][0])
        except:
            tmp.append(0)
    
    feat_dict_step[lbl]=tmp
    print(i,tmp)
    #break
"""
    try:
        feat_dict_start[feature_importance_col_names[index]]=trial.tensor(f).values()[start][0]
    except:
        feat_dict_start[feature_importance_col_names[index]]=0
    break
"""
print(feat_dict_step)
# Out:
# 0 [0.02722787051044308, 0.03848793082364188, 0.04409085815096932, 0.04624817877623976, 0.05045705142798697, 0.048827799435929437, 0.04253425662089227]
# 1 [0.009009122091125718, 0.008290309998087152, 0.009060705560385433, 0.010256487790031122, 0.01072906345815611, 0.010762537505265622, 0.010870330013126978]
# 2 [0.01031906218749337, 0.010526760323318793, 0.012009229322761345, 0.012235026823391391, 0.012329600503508587, 0.01258326010559439, 0.012650703218202188]
# 3 [0.01475625353788844, 0.010575829076127495, 0.016152749624503842, 0.015797586970425076, 0.015940190982052793, 0.01647206336055617, 0.01572898313537444]
# 4 [0.014114714010284492, 0.013580895859037635, 0.01432005074599019, 0.015193668630260298, 0.01577002998842963, 0.014621700334522498, 0.014759957743067136]
# 5 [0.02385519240067875, 0.01654483818675013, 0.014443337939881642, 0.01299408738489515, 0.0129599491755342, 0.013455982900583554, 0.013421987394814906]
# 6 [0.0206185268855578, 0.02286495961210611, 0.026728811800296355, 0.02529271081468422, 0.025636965665411068, 0.025183073842552684, 0.026961579930961006]
# 7 [0.012603031099700412, 0.034437732301163024, 0.03759023874304173, 0.03021036396877176, 0.029281277449688507, 0.029300933373895124, 0.029672270008918113]
# 8 [0.02526694678476011, 0.01703111694779912, 0.019398073380472742, 0.024319778966731657, 0.02093022630889132, 0.022014437534260866, 0.021346437536368872]
xval=[i for i in range(start,ende+1,step)]
val_high = 0
lbl_high = ""
fig,ax = plt.subplots(figsize=(10,10))
for k,yval in feat_dict_step.items():
    #print(k,yval)
    #break
    if yval[-1] > val_high:
        val_high = yval[-1]
        lbl_high = k
    plt.plot(xval,yval)
    
ax.text(xval[-1]-20,val_high+0.001,lbl_high.replace(" ","\n"),horizontalalignment='center',fontsize=20)
plt.title(f'Feature Importances', fontsize=20)
plt.xlabel('runs', fontsize=20)
plt.ylabel('share', fontsize=20)    

save_it=True
if save_it == True:
    from datetime import datetime

    now = datetime.now() # current date and time
    time = now.strftime("%m-%d-%Y-%H-%M-%S")
    filename='Feature_importance by iteraton-'+time
    plt.savefig(filename, dpi=None, facecolor='w', edgecolor='w',
        orientation='portrait')
plt.show()

# %%
#!pip install smdebug
from smdebug.trials import create_trial
s3_output_path = xgboost_debugger.latest_job_debugger_artifacts_path()
trial = create_trial(s3_output_path)
# Out:
# [2020-11-19 21:42:54.461 ip-172-16-29-248:6872 INFO s3_trial.py:42] Loading trial debug-output at path s3://aida-project/team_remote/output/JPC-xgboost-debug-2020-11-19-20-42-34-913/debug-output

# %%
#trial.tensor_names()

# %%
trial.tensor("feature_importance/cover/f0").values()
# Out:
# [2020-11-19 21:42:57.308 ip-172-16-29-248:6872 INFO trial.py:198] Training has ended, will refresh one final time in 1 sec.
# [2020-11-19 21:42:58.328 ip-172-16-29-248:6872 INFO trial.py:210] Loaded all steps
# {50: array([0.02722787]),
#  100: array([0.03848793]),
#  150: array([0.04409086]),
#  200: array([0.04624818]),
#  250: array([0.05045705]),
#  300: array([0.0488278]),
#  350: array([0.04253426])}

# %%
liste = trial.tensor_names()

# %%
#[k for k in lst if 'ab' in k]
feature_importance_names = [k for k in liste if 'feature_importance/cover' in k]
feature_importance_col_names = ['isAdult', 'startYear', 'endYear', 'numVotes', 'Crime', 'Romance', 'Thriller', 'Adventure', 'Drama', 'War', 'Documentary', 'Reality-TV', 'Family', 'Fantasy', 'Game-Show', 'Adult', 'History', 'Mystery', 'Musical', 'Animation', 'Music', 'Film-Noir', 'shortGenre', 'Horror', 'Western', 'Biography', 'Comedy', 'Action', 'Sport', 'Talk-Show', 'Sci-Fi', 'News', 'movie', 'short', 'tvEpisode', 'tvMiniSeries', 'tvMovie', 'tvSeries', 'tvShort', 'tvSpecial', 'video', 'videoGame', 'distinct languages', 'distinct regions']
feature_importance_weight = [k for k in liste if 'feature_importance/weight' in k]

# %%
feat_dict_start={}
feat_dict_ende={}
start=50
ende=350
for i,f in enumerate(feature_importance_names):
    #print(feature_importance_col_names[i],"\t\t",end='')
    #print(trial.tensor(f).values())
    #print(trial.tensor(f).values()[40][0])
    index=int(f.split('f')[2])
    try:
        feat_dict_start[feature_importance_col_names[index]]=trial.tensor(f).values()[start][0]
    except:
        feat_dict_start[feature_importance_col_names[index]]=0
    #break
print(feat_dict_start)
for i,f in enumerate(feature_importance_names):
    index=int(f.split('f')[2])
# %%
feat_weight_dict={}
for i,f in enumerate(feature_importance_weight):
    index=int(f.split('f')[2])
    print(feature_importance_col_names[index],"\t\t",end='')
    print("i,f:",str(i)," ", f)
    print(trial.tensor(f).values())
    #print(trial.tensor(f).values()[40][0])
    feat_weight_dict[feature_importance_col_names[index]]=trial.tensor(f).values()[ende][0]
    #break
#print(feat_weight_dict)
# Out:
# isAdult 		i,f: 0   feature_importance/weight/f0
# {50: array([0.00517799]), 100: array([0.00417851]), 150: array([0.0036921]), 200: array([0.00322553]), 250: array([0.00286553]), 300: array([0.00263158]), 350: array([0.00274806])}
# startYear 		i,f: 1   feature_importance/weight/f1
# {0: array([0.23728814]), 50: array([0.17702265]), 100: array([0.18251713]), 150: array([0.18348624]), 200: array([0.18292165]), 250: array([0.18475814]), 300: array([0.18655606]), 350: array([0.18623025])}
# Documentary 		i,f: 2   feature_importance/weight/f10
# {0: array([0.05084746]), 50: array([0.02071197]), 100: array([0.01938827]), 150: array([0.01834862]), 200: array([0.01833461]), 250: array([0.01767074]), 300: array([0.01767735]), 350: array([0.01746982])}
# Reality-TV 		i,f: 3   feature_importance/weight/f11
# {0: array([0.05084746]), 50: array([0.01262136]), 100: array([0.0153769]), 150: array([0.01376147]), 200: array([0.01298701]), 250: array([0.01234905]), 300: array([0.01229977]), 350: array([0.01290608])}
# Family 		i,f: 4   feature_importance/weight/f12
# {50: array([0.01877023]), 100: array([0.01838543]), 150: array([0.01801298]), 200: array([0.01850437]), 250: array([0.01896705]), 300: array([0.01864989]), 350: array([0.01805869])}
# Fantasy 		i,f: 5   feature_importance/weight/f13
# {50: array([0.00744337]), 100: array([0.01019555]), 150: array([0.01219512]), 200: array([0.01264748]), 250: array([0.0124855]), 300: array([0.01212815]), 350: array([0.01177741])}
# Game-Show 		i,f: 6   feature_importance/weight/f14
# {0: array([0.01694915]), 50: array([0.00841424]), 100: array([0.00869129]), 150: array([0.00816738]), 200: array([0.00763942]), 250: array([0.00818721]), 300: array([0.00789474]), 350: array([0.00819511])}
# Adult 		i,f: 7   feature_importance/weight/f15
# {50: array([0.00355987]), 100: array([0.00317566]), 150: array([0.00279705]), 200: array([0.00297089]), 250: array([0.00272907]), 300: array([0.0028032]), 350: array([0.00279713])}
# History 		i,f: 8   feature_importance/weight/f16
# {50: array([0.00485437]), 100: array([0.00618419]), 150: array([0.00626538]), 200: array([0.00619642]), 250: array([0.00607218]), 300: array([0.00646453]), 350: array([0.00623221])}
# Mystery 		i,f: 9   feature_importance/weight/f17
# {50: array([0.00873786]), 100: array([0.00902557]), 150: array([0.00906243]), 200: array([0.00959172]), 250: array([0.00975643]), 300: array([0.00955378]), 350: array([0.00986358])}
# Musical 		i,f: 10   feature_importance/weight/f18
# {50: array([0.00647249]), 100: array([0.00601705]), 150: array([0.00548221]), 200: array([0.00517783]), 250: array([0.00498056]), 300: array([0.0048627]), 350: array([0.00495633])}
# Animation 		i,f: 11   feature_importance/weight/f19
# {0: array([0.01694915]), 50: array([0.0223301]), 100: array([0.01938827]), 150: array([0.01935556]), 200: array([0.01765555]), 250: array([0.01726138]), 300: array([0.01676201]), 350: array([0.01648837])}
# endYear 		i,f: 12   feature_importance/weight/f2
# {0: array([0.01694915]), 50: array([0.04563107]), 100: array([0.0469664]), 150: array([0.05292012]), 200: array([0.05440964]), 250: array([0.05410384]), 300: array([0.05434783]), 350: array([0.05437236])}
# Music 		i,f: 13   feature_importance/weight/f20
# {50: array([0.02038835]), 100: array([0.01888685]), 150: array([0.01655851]), 200: array([0.01578813]), 250: array([0.01562393]), 300: array([0.01533181]), 350: array([0.0153597])}
# Film-Noir 		i,f: 14   feature_importance/weight/f21
# {100: array([0.00033428]), 150: array([0.00044753]), 200: array([0.00042441]), 250: array([0.00034113]), 300: array([0.00028604]), 350: array([0.00024536])}
# shortGenre 		i,f: 15   feature_importance/weight/f22
# {50: array([0.01391586]), 100: array([0.01337122]), 150: array([0.01320206]), 200: array([0.01247772]), 250: array([0.01289486]), 300: array([0.0125286]), 350: array([0.01320051])}
# Horror 		i,f: 16   feature_importance/weight/f23
# {0: array([0.08474576]), 50: array([0.02297735]), 100: array([0.01855257]), 150: array([0.0179011]), 200: array([0.01646719]), 250: array([0.01521457]), 300: array([0.01481693]), 350: array([0.01452547])}
# Western 		i,f: 17   feature_importance/weight/f24
# {50: array([0.00453074]), 100: array([0.00367709]), 150: array([0.00358022]), 200: array([0.00356506]), 250: array([0.00341134]), 300: array([0.00320366]), 350: array([0.00328786])}
# Biography 		i,f: 18   feature_importance/weight/f25
# {0: array([0.01694915]), 50: array([0.00582524]), 100: array([0.00584991]), 150: array([0.00559409]), 200: array([0.00568712]), 250: array([0.0055946]), 300: array([0.0055492]), 350: array([0.00559427])}
# Comedy 		i,f: 19   feature_importance/weight/f26
# {50: array([0.03559871]), 100: array([0.03142236]), 150: array([0.03412397]), 200: array([0.03471692]), 250: array([0.03411339]), 300: array([0.03323799]), 350: array([0.03263323])}
# Action 		i,f: 20   feature_importance/weight/f27
# {50: array([0.0223301]), 100: array([0.02156109]), 150: array([0.02181696]), 200: array([0.02130549]), 250: array([0.02108208]), 300: array([0.01956522]), 350: array([0.01923643])}
# Sport 		i,f: 21   feature_importance/weight/f28
# {50: array([0.01132686]), 100: array([0.01086411]), 150: array([0.0098456]), 200: array([0.00840336]), 250: array([0.00818721]), 300: array([0.00800915]), 350: array([0.00740995])}
# Talk-Show 		i,f: 22   feature_importance/weight/f29
# {0: array([0.01694915]), 50: array([0.01294498]), 100: array([0.01169982]), 150: array([0.01197136]), 200: array([0.01171378]), 250: array([0.01125742]), 300: array([0.01092677]), 350: array([0.01055059])}
# numVotes 		i,f: 23   feature_importance/weight/f3
# {0: array([0.23728814]), 50: array([0.20614887]), 100: array([0.21310379]), 150: array([0.21402998]), 200: array([0.22154316]), 250: array([0.22808215]), 300: array([0.23323799]), 350: array([0.23721661])}
# Sci-Fi 		i,f: 24   feature_importance/weight/f30
# {50: array([0.01067961]), 100: array([0.01153268]), 150: array([0.01062878]), 200: array([0.01078007]), 250: array([0.0104387]), 300: array([0.01024027]), 350: array([0.01055059])}
# News 		i,f: 25   feature_importance/weight/f31
# {0: array([0.01694915]), 50: array([0.00744337]), 100: array([0.00584991]), 150: array([0.00760797]), 200: array([0.0067906]), 250: array([0.00682268]), 300: array([0.00703661]), 350: array([0.00701737])}
# movie 		i,f: 26   feature_importance/weight/f32
# {0: array([0.01694915]), 50: array([0.01521036]), 100: array([0.01571118]), 150: array([0.01655851]), 200: array([0.01655208]), 250: array([0.01569216]), 300: array([0.01561785]), 350: array([0.0148199])}
# short 		i,f: 27   feature_importance/weight/f33
# {50: array([0.00873786]), 100: array([0.00902557]), 150: array([0.00872678]), 200: array([0.00806383]), 250: array([0.00730027]), 300: array([0.00715103]), 350: array([0.00682108])}
# tvEpisode 		i,f: 28   feature_importance/weight/f34
# {0: array([0.01694915]), 50: array([0.02653722]), 100: array([0.02590674]), 150: array([0.02383083]), 200: array([0.02215432]), 250: array([0.02053626]), 300: array([0.01973684]), 350: array([0.01884385])}
# tvMiniSeries 		i,f: 29   feature_importance/weight/f35
# {50: array([0.0012945]), 100: array([0.00233996]), 150: array([0.00257328]), 200: array([0.00271624]), 250: array([0.0027973]), 300: array([0.00337529]), 350: array([0.00328786])}
# tvMovie 		i,f: 30   feature_importance/weight/f36
# {0: array([0.01694915]), 50: array([0.00711974]), 100: array([0.00869129]), 150: array([0.00783173]), 200: array([0.00755454]), 250: array([0.00757317]), 300: array([0.00715103]), 350: array([0.00716459])}
# tvSeries 		i,f: 31   feature_importance/weight/f37
# {50: array([0.01165049]), 100: array([0.01002841]), 150: array([0.01040501]), 200: array([0.01001613]), 250: array([0.01023402]), 300: array([0.00995423]), 350: array([0.01025616])}
# tvShort 		i,f: 32   feature_importance/weight/f38
# {50: array([0.00097087]), 100: array([0.00200568]), 150: array([0.00179011]), 200: array([0.00178253]), 250: array([0.00170567]), 300: array([0.00160183]), 350: array([0.00166847])}
# tvSpecial 		i,f: 33   feature_importance/weight/f39
# {50: array([0.00550162]), 100: array([0.00551563]), 150: array([0.00514657]), 200: array([0.00500806]), 250: array([0.00491233]), 300: array([0.00474828]), 350: array([0.00480911])}
# Crime 		i,f: 34   feature_importance/weight/f4
# {50: array([0.01165049]), 100: array([0.01236838]), 150: array([0.01253077]), 200: array([0.01358119]), 250: array([0.01391826]), 300: array([0.01338673]), 350: array([0.01374031])}
# video 		i,f: 35   feature_importance/weight/f40
# {0: array([0.01694915]), 50: array([0.01521036]), 100: array([0.01504262]), 150: array([0.01488029]), 200: array([0.01324166]), 250: array([0.01289486]), 300: array([0.01264302]), 350: array([0.01261164])}
# videoGame 		i,f: 36   feature_importance/weight/f41
# {50: array([0.00226537]), 100: array([0.00233996]), 150: array([0.0024614]), 200: array([0.00263136]), 250: array([0.00266084]), 300: array([0.00286041]), 350: array([0.00289528])}
# distinct languages 		i,f: 37   feature_importance/weight/f42
# {0: array([0.06779661]), 50: array([0.03365696]), 100: array([0.03259234]), 150: array([0.03155068]), 200: array([0.03234021]), 250: array([0.03186191]), 300: array([0.03112128]), 350: array([0.03076848])}
# distinct regions 		i,f: 38   feature_importance/weight/f43
# {0: array([0.06779661]), 50: array([0.06472492]), 100: array([0.06551897]), 150: array([0.06455583]), 200: array([0.06629318]), 250: array([0.06583885]), 300: array([0.06767735]), 350: array([0.0680636])}
# Romance 		i,f: 39   feature_importance/weight/f5
# {50: array([0.01488673]), 100: array([0.01604546]), 150: array([0.01532781]), 200: array([0.01578813]), 250: array([0.01671556]), 300: array([0.0166476]), 350: array([0.01658651])}
# Thriller 		i,f: 40   feature_importance/weight/f6
# {50: array([0.00841424]), 100: array([0.00919271]), 150: array([0.00917431]), 200: array([0.01001613]), 250: array([0.01023402]), 300: array([0.01001144]), 350: array([0.009471])}
# Adventure 		i,f: 41   feature_importance/weight/f7
# {50: array([0.02135922]), 100: array([0.01738258]), 150: array([0.01756545]), 200: array([0.01689161]), 250: array([0.01657911]), 300: array([0.01601831]), 350: array([0.01624301])}
# Drama 		i,f: 42   feature_importance/weight/f8
# {0: array([0.03389831]), 50: array([0.03300971]), 100: array([0.03209092]), 150: array([0.03155068]), 200: array([0.03038791]), 250: array([0.02988333]), 300: array([0.02957666]), 350: array([0.02914908])}
# War 		i,f: 43   feature_importance/weight/f9
# {50: array([0.00194175]), 100: array([0.00200568]), 150: array([0.00268516]), 200: array([0.00305577]), 250: array([0.00341134]), 300: array([0.00411899]), 350: array([0.00387673])}

# %%
import matplotlib.pyplot as plt
plt.bar(range(len(feat_dict_start)),list(feat_dict_start.values()))
plt.title(f"Feature_importances (after {start} training steps)", fontsize=20)
plt.show()
plt.bar(range(len(feat_dict_ende)),list(feat_dict_ende.values()))
plt.title(f"Feature_importances (after {ende} training steps)", fontsize=20)
# Out:
# Text(0.5, 1.0, 'Feature_importances (after 350 training steps)')

# %%
plt.bar(range(len(feat_weight_dict)),list(feat_weight_dict.values()))
plt.title("Feature_importances_weight", fontsize=20)
# Out:
# Text(0.5, 1.0, 'Feature_importances_weight')

# %%
import pandas as pd

# %%
from datetime import datetime

now = datetime.now() # current date and time
time = now.strftime("%m-%d-%Y-%H-%M-%S")
#print(time)

dict = feat_dict_ende

fig,ax = plt.subplots(figsize=(20,10))

#pd.DataFrame(feat_dict, index=['quantity']).plot(kind='bar',ax=ax,use_index=False, legend=False,width=1.4)
plt.bar(*zip(*dict.items()))
plt.title(f'Feature Importances ({ende} runs)', fontsize=20)
plt.xlabel('Feature', fontsize=20)
plt.ylabel('share', fontsize=20)
plt.xticks(ticks=[])
threshold=0.038
pad=0.001
i=0
for k,v in dict.items():
    if v > threshold:
        ax.text(i,v+pad,k.replace(" ","\n"),horizontalalignment='center',fontsize=20)
    #reak
    i +=1
#plt.xlim([0,10])
#plt.ylim([0,10])
#plt.plot([0,10],[0,10], c='red')

#plt.show()
save_it=True
if save_it == True:
    filename='Feature_importance_1-'+time
    plt.savefig(filename, dpi=None, facecolor='w', edgecolor='w',
        orientation='portrait')
plt.show()

# %%
sum=0
for k,v in feat_dict_ende.items():
    sum=sum+v
print(round(sum,7))
# Out:
# 1.0

# %% [markdown]
# # Deploy Model

# %% [markdown]
# ## Deploy

# %%
# Deploy  model to an endpoint

xgb_predictor = xgboost_debugger.deploy(
    initial_instance_count = 1, 
    instance_type = 'ml.t2.medium')
# Out:
# Parameter image will be renamed to image_uri in SageMaker Python SDK v2.
# -------------!

# %% [markdown]
# ## Configure Predictor

# %%
# Configure the predictor's serializer and deserializer

# INSERT CODE HERE

from sagemaker.predictor import csv_serializer, json_deserializer

xgb_predictor.content_type = "text/csv"
xgb_predictor.serializer = csv_serializer
xgb_predictor.deserializer = json_deserializer

# %% [markdown]
# # Display Endpoint

# %%
xgb_predictor.endpoint
# Out:
# 'JPC-xgboost-debug-2020-11-19-20-42-34-913'

# %% [markdown]
# # Prediction

# %%
# carefully just one prediction
import pandas as pd
import matplotlib.pyplot as plt

#col_names = ['averageRating', 'isAdult', 'startYear', 'endYear', 'numVotes', 'Crime', 'Romance', 'Thriller', 'Adventure', 'Drama', 'War', 'Documentary', 'Reality-TV', 'Family', 'Fantasy', 'Game-Show', 'Adult', 'History', 'Mystery', 'Musical', 'Animation', 'Music', 'Film-Noir', 'shortGenre', 'Horror', 'Western', 'Biography', 'Comedy', 'Action', 'Sport', 'Talk-Show', 'Sci-Fi', 'News', 'movie', 'short', 'tvEpisode', 'tvMiniSeries', 'tvMovie', 'tvSeries', 'tvShort', 'tvSpecial', 'video', 'videoGame', 'distinct languages', 'distinct regions']
test = pd.read_csv(f"{s3_path}{test_source_path}/{test_source_name}", header=0, index_col=False, names=feature_importance_col_names)
prediction=[]
for i in range(test.shape[0]):
    prediction.append(xgb_predictor.predict(test.iloc[i, 1:]))
    if i % 5000 == 0:
        print(i)
    #     print(prediction)
    #     print(test.iloc[i,0])
#print(prediction) 

#plt.scatter(test.iloc[:,0], prediction)
# Out:
# 0
# 5000
# 10000
# 15000
# 20000
# 25000
# 30000
# 35000
# 40000
# 45000
# 50000
# 55000
# 60000
# 65000
# 70000
# 75000
# 80000
# 85000
# 90000
# 95000

# %%
from datetime import datetime

now = datetime.now() # current date and time
time = now.strftime("%m-%d-%Y-%H-%M-%S")
print(time)



fig = plt.subplots(figsize=(10,10))
plt.scatter(test.iloc[:,0], prediction,marker='.',alpha=0.3)
plt.title(f'eta and alpha optimization Prediction (train data) {ende} steps', fontsize=20)
plt.xlabel('original value')
plt.ylabel('predicted value')
plt.xlim([0,10])
plt.ylim([0,10])
plt.plot([0,10],[0,10], c='red')

#plt.show()
filename='Prediction-'+time
plt.savefig(filename, dpi=None, facecolor='w', edgecolor='w',
        orientation='portrait')
# Out:
# 11-19-2020-22-12-03

# %%
# Out:
# 11-18-2020-14-55-10
