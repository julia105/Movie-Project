# %% [markdown]
# # Initialize

# %% [markdown]
# ## ASW session

# %%
import boto3

session = boto3.Session()
s3 = session.resource('s3')

# %% [markdown]
# ## SageMaker Session

# %%
import sagemaker

sage_session = sagemaker.Session()

# %% [markdown]
# # Define Globals

# %%
# bucket name
bucket = 'aida-project'

# path for s3_input
s3_path = f"s3://{bucket}/"

## define source files
# TRAIN source file
train_source_path = 'team_remote'
train_source_name = 'title-train-princ4.csv'
#train_source_name = 'title-valid.csv'       # for testing; remove later


# VALID source file
valid_source_path = 'team_remote'
valid_source_name = 'title-valid-princ4.csv'
#valid_source_name = 'title-test.csv'       # for testing; remove later

# TEST source file
test_source_path = 'team_remote'
test_source_name = 'title-test-princ4.csv'

# output for result
output_path ='team_remote'
output_location = f'{s3_path}{output_path}/output'

# %%
print(output_location)
# Out:
# s3://aida-project/team_remote/output

# %%
# Create pointers to the S3 train and test datasets

from sagemaker import s3_input

# print(f"{s3_path}{train_source_path}/{train_source_name}")
# print(f"{s3_path}{valid_source_path}/{valid_source_name}")
# print(f"{s3_path}{test_source_path}/{test_source_name}")
s3_input_train = sagemaker.session.s3_input(s3_data=f"{s3_path}{train_source_path}/{train_source_name}", content_type="text/csv")
s3_input_valid = sagemaker.session.s3_input(s3_data=f"{s3_path}{valid_source_path}/{valid_source_name}", content_type="text/csv")
s3_input_test = sagemaker.session.s3_input(s3_data=f"{s3_path}{test_source_path}/{test_source_name}", content_type="text/csv")
# Out:
# 's3_input' class will be renamed to 'TrainingInput' in SageMaker Python SDK v2.
# 's3_input' class will be renamed to 'TrainingInput' in SageMaker Python SDK v2.
# 's3_input' class will be renamed to 'TrainingInput' in SageMaker Python SDK v2.

# %%
role = sagemaker.get_execution_role()

# %% [markdown]
# # Define Model

# %%
# finde pre-defined models here:
# https://docs.aws.amazon.com/sagemaker/latest/dg/sagemaker-algo-docker-registry-paths.html

# Create an XGBoost Estimator

# estimator call
# <ecr_path>/sagemaker-xgboost:1.2-1
    
ecr_path = "492215442770.dkr.ecr.eu-central-1.amazonaws.com"
xgboost_estimator = f"{ecr_path}/sagemaker-xgboost:1.0-1-cpu-py3"

# ecr_path = "664544806723.dkr.ecr.eu-central-1.amazonaws.com"
# knn_estimator = f"{ecr_path}/knn:latest"

# %%
xgboost = sagemaker.estimator.Estimator(xgboost_estimator,
                              role,
                              train_instance_count=1,
                              train_instance_type="ml.m5.4xlarge",
                              output_path=output_location,
                              sagemaker_session=sage_session,
                              base_job_name="JPC-xgboost")
# Out:
# Parameter image_name will be renamed to image_uri in SageMaker Python SDK v2.

# %%
# Select the your specific hyperparameters (Optional)
# https://docs.aws.amazon.com/sagemaker/latest/dg/xgboost_hyperparameters.html
# https://github.com/dmlc/xgboost/blob/master/doc/parameter.rst#learning-task-parameters 

xgboost.set_hyperparameters(
    eta=.35,
    num_round=252,                     # required parameter!
    objective = 'reg:linear',
    )

# %%
from sagemaker.debugger import rule_configs, Rule, DebuggerHookConfig, CollectionConfig
from sagemaker.estimator import Estimator 
save_interval = 50
xgboost_debugger = Estimator( role=role, 
                             base_job_name="JPC-xgboost-debug", 
                             train_instance_count=1, 
                             train_instance_type='ml.m5.4xlarge', 
                             image_name=xgboost_estimator, 
                             train_max_run=1800, 
                             debugger_hook_config=DebuggerHookConfig( s3_output_path=output_location, # Required 
                             collection_configs=[ CollectionConfig( name="feature_importance", parameters={ "save_interval": str(save_interval) } ), ], ), 
                              rules=[ Rule.sagemaker( rule_configs.loss_not_decreasing(), 
                                                     rule_parameters={ "collection_names": "metrics", "num_steps": str(save_interval * 2), }, ), ],
)
xgboost_debugger.set_hyperparameters(
    eta=.45,
    # gamma=0.5,
    alpha = 0.55,
    #lambda_bias=0.4,
    num_round=452
    #booster = 'dart'
    #objective = 'reg:linear',
    )
# Out:
# Parameter image_name will be renamed to image_uri in SageMaker Python SDK v2.

# %% [markdown]
# ## Fit Model

# %%
xgboost_debugger.fit({"train": s3_input_train, "validation": s3_input_valid}, wait=True)
# Out:
# 2020-11-20 08:25:39 Starting - Starting the training job...
# 2020-11-20 08:25:41 Starting - Launching requested ML instances
# ********* Debugger Rule Status *********
# *
# *  LossNotDecreasing: InProgress
# *
# ****************************************
# ......
# 2020-11-20 08:27:05 Starting - Preparing the instances for training...
# 2020-11-20 08:27:38 Downloading - Downloading input data...
# 2020-11-20 08:28:08 Training - Training image download completed. Training in progress..INFO:sagemaker-containers:Imported framework sagemaker_xgboost_container.training
# INFO:sagemaker-containers:No GPUs detected (normal if no gpus installed)
# INFO:sagemaker_xgboost_container.training:Running XGBoost Sagemaker in algorithm mode
# INFO:root:Determined delimiter of CSV input is ','
# INFO:root:Determined delimiter of CSV input is ','
# INFO:root:Determined delimiter of CSV input is ','
# [08:28:12] 804606x74 matrix with 59540844 entries loaded from /opt/ml/input/data/train?format=csv&label_column=0&delimiter=,
# INFO:root:Determined delimiter of CSV input is ','
# [08:28:12] 89652x74 matrix with 6634248 entries loaded from /opt/ml/input/data/validation?format=csv&label_column=0&delimiter=,
# INFO:root:Single node training.
# [2020-11-20 08:28:12.930 ip-10-0-92-112.eu-central-1.compute.internal:1 INFO json_config.py:90] Creating hook from json_config at /opt/ml/input/config/debughookconfig.json.
# [2020-11-20 08:28:12.931 ip-10-0-92-112.eu-central-1.compute.internal:1 INFO hook.py:151] tensorboard_dir has not been set for the hook. SMDebug will not be exporting tensorboard summaries.
# [2020-11-20 08:28:12.931 ip-10-0-92-112.eu-central-1.compute.internal:1 INFO hook.py:196] Saving to /opt/ml/output/tensors
# INFO:root:Debug hook created from config
# INFO:root:Train matrix has 804606 rows
# INFO:root:Validation matrix has 89652 rows
# [08:28:12] WARNING: /workspace/src/learner.cc:328:
# Parameters: { num_round } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [0]#011train-rmse:3.74260#011validation-rmse:3.73616
# [2020-11-20 08:28:13.866 ip-10-0-92-112.eu-central-1.compute.internal:1 INFO hook.py:325] Monitoring the collections: losses, feature_importance, metrics
# [1]#011train-rmse:2.29959#011validation-rmse:2.29350
# [2]#011train-rmse:1.62366#011validation-rmse:1.61791
# [3]#011train-rmse:1.34898#011validation-rmse:1.34348
# [4]#011train-rmse:1.24913#011validation-rmse:1.24372
# [5]#011train-rmse:1.21256#011validation-rmse:1.20692
# [6]#011train-rmse:1.20115#011validation-rmse:1.19581
# [7]#011train-rmse:1.19616#011validation-rmse:1.19113
# [8]#011train-rmse:1.18975#011validation-rmse:1.18496
# [9]#011train-rmse:1.18749#011validation-rmse:1.18293
# [10]#011train-rmse:1.18363#011validation-rmse:1.17934
# [11]#011train-rmse:1.18135#011validation-rmse:1.17718
# [12]#011train-rmse:1.17954#011validation-rmse:1.17563
# [13]#011train-rmse:1.17751#011validation-rmse:1.17387
# [14]#011train-rmse:1.17562#011validation-rmse:1.17200
# [15]#011train-rmse:1.17468#011validation-rmse:1.17128
# [16]#011train-rmse:1.17397#011validation-rmse:1.17075
# [17]#011train-rmse:1.17328#011validation-rmse:1.17003
# [18]#011train-rmse:1.17181#011validation-rmse:1.16859
# [19]#011train-rmse:1.16956#011validation-rmse:1.16649
# [20]#011train-rmse:1.16683#011validation-rmse:1.16396
# [21]#011train-rmse:1.16546#011validation-rmse:1.16274
# [22]#011train-rmse:1.16436#011validation-rmse:1.16163
# [23]#011train-rmse:1.16360#011validation-rmse:1.16096
# [24]#011train-rmse:1.16299#011validation-rmse:1.16048
# [25]#011train-rmse:1.16211#011validation-rmse:1.15953
# [26]#011train-rmse:1.16139#011validation-rmse:1.15897
# [27]#011train-rmse:1.16057#011validation-rmse:1.15840
# [28]#011train-rmse:1.15979#011validation-rmse:1.15778
# [29]#011train-rmse:1.15884#011validation-rmse:1.15686
# [30]#011train-rmse:1.15803#011validation-rmse:1.15595
# [31]#011train-rmse:1.15793#011validation-rmse:1.15590
# [32]#011train-rmse:1.15595#011validation-rmse:1.15418
# [33]#011train-rmse:1.15500#011validation-rmse:1.15351
# [34]#011train-rmse:1.15456#011validation-rmse:1.15314
# [35]#011train-rmse:1.15388#011validation-rmse:1.15254
# [36]#011train-rmse:1.15378#011validation-rmse:1.15246
# [37]#011train-rmse:1.15319#011validation-rmse:1.15185
# [38]#011train-rmse:1.15303#011validation-rmse:1.15173
# [39]#011train-rmse:1.15216#011validation-rmse:1.15078
# [40]#011train-rmse:1.15202#011validation-rmse:1.15070
# [41]#011train-rmse:1.15200#011validation-rmse:1.15066
# [42]#011train-rmse:1.15199#011validation-rmse:1.15067
# [43]#011train-rmse:1.15182#011validation-rmse:1.15058
# [44]#011train-rmse:1.15090#011validation-rmse:1.14965
# [45]#011train-rmse:1.15039#011validation-rmse:1.14924
# [46]#011train-rmse:1.14957#011validation-rmse:1.14859
# [47]#011train-rmse:1.14926#011validation-rmse:1.14831
# [48]#011train-rmse:1.14877#011validation-rmse:1.14790
# [49]#011train-rmse:1.14817#011validation-rmse:1.14746
# [50]#011train-rmse:1.14787#011validation-rmse:1.14719
# [51]#011train-rmse:1.14668#011validation-rmse:1.14619
# [52]#011train-rmse:1.14634#011validation-rmse:1.14589
# [53]#011train-rmse:1.14550#011validation-rmse:1.14530
# [54]#011train-rmse:1.14511#011validation-rmse:1.14495
# [55]#011train-rmse:1.14468#011validation-rmse:1.14470
# [56]#011train-rmse:1.14462#011validation-rmse:1.14468
# [57]#011train-rmse:1.14405#011validation-rmse:1.14421
# [58]#011train-rmse:1.14404#011validation-rmse:1.14417
# [59]#011train-rmse:1.14387#011validation-rmse:1.14402
# [60]#011train-rmse:1.14336#011validation-rmse:1.14362
# [61]#011train-rmse:1.14316#011validation-rmse:1.14344
# [62]#011train-rmse:1.14265#011validation-rmse:1.14306
# [63]#011train-rmse:1.14126#011validation-rmse:1.14196
# [64]#011train-rmse:1.14123#011validation-rmse:1.14196
# [65]#011train-rmse:1.14059#011validation-rmse:1.14160
# [66]#011train-rmse:1.13983#011validation-rmse:1.14081
# [67]#011train-rmse:1.13943#011validation-rmse:1.14040
# [68]#011train-rmse:1.13895#011validation-rmse:1.13993
# [69]#011train-rmse:1.13840#011validation-rmse:1.13959
# [70]#011train-rmse:1.13794#011validation-rmse:1.13923
# [71]#011train-rmse:1.13752#011validation-rmse:1.13885
# [72]#011train-rmse:1.13724#011validation-rmse:1.13860
# [73]#011train-rmse:1.13677#011validation-rmse:1.13826
# [74]#011train-rmse:1.13641#011validation-rmse:1.13796
# [75]#011train-rmse:1.13595#011validation-rmse:1.13748
# [76]#011train-rmse:1.13562#011validation-rmse:1.13728
# [77]#011train-rmse:1.13521#011validation-rmse:1.13697
# [78]#011train-rmse:1.13511#011validation-rmse:1.13685
# [79]#011train-rmse:1.13488#011validation-rmse:1.13677
# [80]#011train-rmse:1.13487#011validation-rmse:1.13676
# [81]#011train-rmse:1.13436#011validation-rmse:1.13637
# [82]#011train-rmse:1.13420#011validation-rmse:1.13626
# [83]#011train-rmse:1.13389#011validation-rmse:1.13609
# [84]#011train-rmse:1.13383#011validation-rmse:1.13610
# [85]#011train-rmse:1.13383#011validation-rmse:1.13610
# [86]#011train-rmse:1.13382#011validation-rmse:1.13608
# [87]#011train-rmse:1.13379#011validation-rmse:1.13606
# [88]#011train-rmse:1.13363#011validation-rmse:1.13597
# [89]#011train-rmse:1.13352#011validation-rmse:1.13592
# [90]#011train-rmse:1.13342#011validation-rmse:1.13586
# [91]#011train-rmse:1.13333#011validation-rmse:1.13582
# [92]#011train-rmse:1.13332#011validation-rmse:1.13582
# [93]#011train-rmse:1.13331#011validation-rmse:1.13582
# [94]#011train-rmse:1.13331#011validation-rmse:1.13582
# [95]#011train-rmse:1.13331#011validation-rmse:1.13581
# [96]#011train-rmse:1.13290#011validation-rmse:1.13542
# [97]#011train-rmse:1.13288#011validation-rmse:1.13543
# [98]#011train-rmse:1.13244#011validation-rmse:1.13500
# [99]#011train-rmse:1.13212#011validation-rmse:1.13480
# [100]#011train-rmse:1.13169#011validation-rmse:1.13445
# [101]#011train-rmse:1.13137#011validation-rmse:1.13425
# [102]#011train-rmse:1.13112#011validation-rmse:1.13405
# [103]#011train-rmse:1.13090#011validation-rmse:1.13386
# [104]#011train-rmse:1.13071#011validation-rmse:1.13377
# [105]#011train-rmse:1.13031#011validation-rmse:1.13351
# [106]#011train-rmse:1.13017#011validation-rmse:1.13356
# [107]#011train-rmse:1.12997#011validation-rmse:1.13352
# [108]#011train-rmse:1.12985#011validation-rmse:1.13350
# [109]#011train-rmse:1.12966#011validation-rmse:1.13342
# [110]#011train-rmse:1.12903#011validation-rmse:1.13279
# [111]#011train-rmse:1.12841#011validation-rmse:1.13240
# [112]#011train-rmse:1.12809#011validation-rmse:1.13224
# [113]#011train-rmse:1.12791#011validation-rmse:1.13214
# [114]#011train-rmse:1.12756#011validation-rmse:1.13183
# [115]#011train-rmse:1.12753#011validation-rmse:1.13181
# [116]#011train-rmse:1.12710#011validation-rmse:1.13139
# [117]#011train-rmse:1.12689#011validation-rmse:1.13126
# [118]#011train-rmse:1.12657#011validation-rmse:1.13100
# [119]#011train-rmse:1.12623#011validation-rmse:1.13079
# [120]#011train-rmse:1.12605#011validation-rmse:1.13071
# [121]#011train-rmse:1.12557#011validation-rmse:1.13030
# [122]#011train-rmse:1.12529#011validation-rmse:1.13007
# [123]#011train-rmse:1.12517#011validation-rmse:1.13002
# [124]#011train-rmse:1.12489#011validation-rmse:1.12981
# [125]#011train-rmse:1.12452#011validation-rmse:1.12964
# [126]#011train-rmse:1.12413#011validation-rmse:1.12942
# [127]#011train-rmse:1.12360#011validation-rmse:1.12910
# [128]#011train-rmse:1.12328#011validation-rmse:1.12893
# [129]#011train-rmse:1.12294#011validation-rmse:1.12879
# [130]#011train-rmse:1.12278#011validation-rmse:1.12875
# [131]#011train-rmse:1.12252#011validation-rmse:1.12859
# [132]#011train-rmse:1.12216#011validation-rmse:1.12829
# [133]#011train-rmse:1.12201#011validation-rmse:1.12824
# [134]#011train-rmse:1.12193#011validation-rmse:1.12819
# [135]#011train-rmse:1.12187#011validation-rmse:1.12819
# [136]#011train-rmse:1.12186#011validation-rmse:1.12819
# [137]#011train-rmse:1.12186#011validation-rmse:1.12818
# [138]#011train-rmse:1.12183#011validation-rmse:1.12818
# [139]#011train-rmse:1.12183#011validation-rmse:1.12818
# [140]#011train-rmse:1.12183#011validation-rmse:1.12818
# [141]#011train-rmse:1.12176#011validation-rmse:1.12812
# [142]#011train-rmse:1.12147#011validation-rmse:1.12793
# [143]#011train-rmse:1.12133#011validation-rmse:1.12794
# [144]#011train-rmse:1.12125#011validation-rmse:1.12791
# [145]#011train-rmse:1.12119#011validation-rmse:1.12794
# [146]#011train-rmse:1.12096#011validation-rmse:1.12781
# [147]#011train-rmse:1.12066#011validation-rmse:1.12777
# [148]#011train-rmse:1.12064#011validation-rmse:1.12777
# [149]#011train-rmse:1.12039#011validation-rmse:1.12766
# [150]#011train-rmse:1.12004#011validation-rmse:1.12733
# [151]#011train-rmse:1.11988#011validation-rmse:1.12726
# [152]#011train-rmse:1.11970#011validation-rmse:1.12719
# [153]#011train-rmse:1.11959#011validation-rmse:1.12722
# [154]#011train-rmse:1.11940#011validation-rmse:1.12718
# [155]#011train-rmse:1.11912#011validation-rmse:1.12703
# [156]#011train-rmse:1.11857#011validation-rmse:1.12651
# [157]#011train-rmse:1.11838#011validation-rmse:1.12641
# [158]#011train-rmse:1.11810#011validation-rmse:1.12623
# [159]#011train-rmse:1.11794#011validation-rmse:1.12615
# [160]#011train-rmse:1.11784#011validation-rmse:1.12611
# [161]#011train-rmse:1.11777#011validation-rmse:1.12602
# [162]#011train-rmse:1.11769#011validation-rmse:1.12589
# [163]#011train-rmse:1.11759#011validation-rmse:1.12587
# [164]#011train-rmse:1.11736#011validation-rmse:1.12566
# [165]#011train-rmse:1.11714#011validation-rmse:1.12556
# [166]#011train-rmse:1.11698#011validation-rmse:1.12555
# [167]#011train-rmse:1.11683#011validation-rmse:1.12542
# [168]#011train-rmse:1.11660#011validation-rmse:1.12527
# [169]#011train-rmse:1.11644#011validation-rmse:1.12520
# [170]#011train-rmse:1.11612#011validation-rmse:1.12510
# [171]#011train-rmse:1.11604#011validation-rmse:1.12504
# [172]#011train-rmse:1.11582#011validation-rmse:1.12489
# [173]#011train-rmse:1.11556#011validation-rmse:1.12475
# [174]#011train-rmse:1.11540#011validation-rmse:1.12472
# [175]#011train-rmse:1.11512#011validation-rmse:1.12447
# [176]#011train-rmse:1.11497#011validation-rmse:1.12445
# [177]#011train-rmse:1.11474#011validation-rmse:1.12433
# [178]#011train-rmse:1.11453#011validation-rmse:1.12421
# [179]#011train-rmse:1.11441#011validation-rmse:1.12416
# [180]#011train-rmse:1.11424#011validation-rmse:1.12409
# [181]#011train-rmse:1.11406#011validation-rmse:1.12403
# [182]#011train-rmse:1.11390#011validation-rmse:1.12397
# [183]#011train-rmse:1.11372#011validation-rmse:1.12390
# [184]#011train-rmse:1.11355#011validation-rmse:1.12387
# [185]#011train-rmse:1.11352#011validation-rmse:1.12386
# [186]#011train-rmse:1.11330#011validation-rmse:1.12366
# [187]#011train-rmse:1.11290#011validation-rmse:1.12326
# [188]#011train-rmse:1.11283#011validation-rmse:1.12324
# [189]#011train-rmse:1.11254#011validation-rmse:1.12299
# [190]#011train-rmse:1.11243#011validation-rmse:1.12294
# [191]#011train-rmse:1.11236#011validation-rmse:1.12295
# [192]#011train-rmse:1.11235#011validation-rmse:1.12295
# [193]#011train-rmse:1.11224#011validation-rmse:1.12292
# [194]#011train-rmse:1.11206#011validation-rmse:1.12285
# [195]#011train-rmse:1.11196#011validation-rmse:1.12281
# [196]#011train-rmse:1.11178#011validation-rmse:1.12268
# [197]#011train-rmse:1.11172#011validation-rmse:1.12269
# [198]#011train-rmse:1.11152#011validation-rmse:1.12257
# [199]#011train-rmse:1.11149#011validation-rmse:1.12255
# [200]#011train-rmse:1.11132#011validation-rmse:1.12247
# [201]#011train-rmse:1.11132#011validation-rmse:1.12247
# [202]#011train-rmse:1.11132#011validation-rmse:1.12247
# [203]#011train-rmse:1.11132#011validation-rmse:1.12247
# [204]#011train-rmse:1.11125#011validation-rmse:1.12245
# [205]#011train-rmse:1.11118#011validation-rmse:1.12243
# [206]#011train-rmse:1.11092#011validation-rmse:1.12229
# [207]#011train-rmse:1.11087#011validation-rmse:1.12230
# [208]#011train-rmse:1.11079#011validation-rmse:1.12228
# [209]#011train-rmse:1.11076#011validation-rmse:1.12228
# [210]#011train-rmse:1.11071#011validation-rmse:1.12229
# [211]#011train-rmse:1.11069#011validation-rmse:1.12230
# [212]#011train-rmse:1.11061#011validation-rmse:1.12232
# [213]#011train-rmse:1.11060#011validation-rmse:1.12232
# [214]#011train-rmse:1.11035#011validation-rmse:1.12218
# [215]#011train-rmse:1.11022#011validation-rmse:1.12209
# [216]#011train-rmse:1.11014#011validation-rmse:1.12211
# [217]#011train-rmse:1.11011#011validation-rmse:1.12212
# [218]#011train-rmse:1.11003#011validation-rmse:1.12213
# [219]#011train-rmse:1.10994#011validation-rmse:1.12210
# [220]#011train-rmse:1.10969#011validation-rmse:1.12192
# [221]#011train-rmse:1.10961#011validation-rmse:1.12190
# [222]#011train-rmse:1.10960#011validation-rmse:1.12190
# [223]#011train-rmse:1.10955#011validation-rmse:1.12190
# [224]#011train-rmse:1.10947#011validation-rmse:1.12193
# [225]#011train-rmse:1.10926#011validation-rmse:1.12171
# [226]#011train-rmse:1.10911#011validation-rmse:1.12168
# [227]#011train-rmse:1.10896#011validation-rmse:1.12161
# [228]#011train-rmse:1.10883#011validation-rmse:1.12159
# [229]#011train-rmse:1.10870#011validation-rmse:1.12157
# [230]#011train-rmse:1.10856#011validation-rmse:1.12153
# [231]#011train-rmse:1.10840#011validation-rmse:1.12142
# [232]#011train-rmse:1.10835#011validation-rmse:1.12142
# [233]#011train-rmse:1.10817#011validation-rmse:1.12126
# [234]#011train-rmse:1.10800#011validation-rmse:1.12114
# [235]#011train-rmse:1.10783#011validation-rmse:1.12106
# [236]#011train-rmse:1.10751#011validation-rmse:1.12087
# [237]#011train-rmse:1.10732#011validation-rmse:1.12082
# [238]#011train-rmse:1.10715#011validation-rmse:1.12072
# [239]#011train-rmse:1.10698#011validation-rmse:1.12059
# [240]#011train-rmse:1.10686#011validation-rmse:1.12052
# [241]#011train-rmse:1.10672#011validation-rmse:1.12041
# [242]#011train-rmse:1.10660#011validation-rmse:1.12037
# [243]#011train-rmse:1.10646#011validation-rmse:1.12031
# [244]#011train-rmse:1.10623#011validation-rmse:1.12030
# [245]#011train-rmse:1.10612#011validation-rmse:1.12023
# [246]#011train-rmse:1.10610#011validation-rmse:1.12025
# [247]#011train-rmse:1.10595#011validation-rmse:1.12020
# [248]#011train-rmse:1.10583#011validation-rmse:1.12016
# [249]#011train-rmse:1.10578#011validation-rmse:1.12019
# [250]#011train-rmse:1.10576#011validation-rmse:1.12018
# [251]#011train-rmse:1.10565#011validation-rmse:1.12018
# [252]#011train-rmse:1.10553#011validation-rmse:1.12012
# [253]#011train-rmse:1.10536#011validation-rmse:1.12008
# [254]#011train-rmse:1.10528#011validation-rmse:1.12006
# [255]#011train-rmse:1.10515#011validation-rmse:1.12000
# [256]#011train-rmse:1.10503#011validation-rmse:1.11997
# [257]#011train-rmse:1.10489#011validation-rmse:1.11990
# [258]#011train-rmse:1.10474#011validation-rmse:1.11980
# [259]#011train-rmse:1.10471#011validation-rmse:1.11980
# [260]#011train-rmse:1.10464#011validation-rmse:1.11978
# [261]#011train-rmse:1.10453#011validation-rmse:1.11978
# [262]#011train-rmse:1.10434#011validation-rmse:1.11963
# [263]#011train-rmse:1.10420#011validation-rmse:1.11960
# [264]#011train-rmse:1.10400#011validation-rmse:1.11946
# [265]#011train-rmse:1.10389#011validation-rmse:1.11947
# [266]#011train-rmse:1.10385#011validation-rmse:1.11949
# [267]#011train-rmse:1.10356#011validation-rmse:1.11928
# [268]#011train-rmse:1.10346#011validation-rmse:1.11925
# [269]#011train-rmse:1.10328#011validation-rmse:1.11909
# [270]#011train-rmse:1.10324#011validation-rmse:1.11907
# [271]#011train-rmse:1.10323#011validation-rmse:1.11908
# [272]#011train-rmse:1.10311#011validation-rmse:1.11903
# [273]#011train-rmse:1.10309#011validation-rmse:1.11903
# [274]#011train-rmse:1.10293#011validation-rmse:1.11898
# [275]#011train-rmse:1.10284#011validation-rmse:1.11895
# [276]#011train-rmse:1.10273#011validation-rmse:1.11892
# [277]#011train-rmse:1.10262#011validation-rmse:1.11889
# [278]#011train-rmse:1.10249#011validation-rmse:1.11887
# [279]#011train-rmse:1.10216#011validation-rmse:1.11860
# [280]#011train-rmse:1.10206#011validation-rmse:1.11852
# [281]#011train-rmse:1.10193#011validation-rmse:1.11843
# [282]#011train-rmse:1.10176#011validation-rmse:1.11843
# [283]#011train-rmse:1.10168#011validation-rmse:1.11840
# [284]#011train-rmse:1.10158#011validation-rmse:1.11839
# [285]#011train-rmse:1.10149#011validation-rmse:1.11840
# [286]#011train-rmse:1.10131#011validation-rmse:1.11833
# [287]#011train-rmse:1.10115#011validation-rmse:1.11831
# [288]#011train-rmse:1.10092#011validation-rmse:1.11820
# [289]#011train-rmse:1.10089#011validation-rmse:1.11818
# [290]#011train-rmse:1.10084#011validation-rmse:1.11818
# [291]#011train-rmse:1.10077#011validation-rmse:1.11817
# [292]#011train-rmse:1.10077#011validation-rmse:1.11817
# [293]#011train-rmse:1.10076#011validation-rmse:1.11817
# [294]#011train-rmse:1.10076#011validation-rmse:1.11817
# [295]#011train-rmse:1.10075#011validation-rmse:1.11817
# [296]#011train-rmse:1.10072#011validation-rmse:1.11814
# [297]#011train-rmse:1.10070#011validation-rmse:1.11813
# [298]#011train-rmse:1.10061#011validation-rmse:1.11816
# [299]#011train-rmse:1.10047#011validation-rmse:1.11810
# [300]#011train-rmse:1.10035#011validation-rmse:1.11807
# [301]#011train-rmse:1.10023#011validation-rmse:1.11800
# [302]#011train-rmse:1.10005#011validation-rmse:1.11795
# [303]#011train-rmse:1.10003#011validation-rmse:1.11795
# [304]#011train-rmse:1.09995#011validation-rmse:1.11794
# [305]#011train-rmse:1.09991#011validation-rmse:1.11794
# [306]#011train-rmse:1.09980#011validation-rmse:1.11790
# [307]#011train-rmse:1.09969#011validation-rmse:1.11784
# [308]#011train-rmse:1.09960#011validation-rmse:1.11781
# [309]#011train-rmse:1.09947#011validation-rmse:1.11777
# [310]#011train-rmse:1.09941#011validation-rmse:1.11775
# [311]#011train-rmse:1.09938#011validation-rmse:1.11773
# [312]#011train-rmse:1.09933#011validation-rmse:1.11773
# [313]#011train-rmse:1.09926#011validation-rmse:1.11774
# [314]#011train-rmse:1.09912#011validation-rmse:1.11767
# [315]#011train-rmse:1.09900#011validation-rmse:1.11762
# [316]#011train-rmse:1.09893#011validation-rmse:1.11754
# [317]#011train-rmse:1.09885#011validation-rmse:1.11754
# [318]#011train-rmse:1.09871#011validation-rmse:1.11746
# [319]#011train-rmse:1.09859#011validation-rmse:1.11742
# [320]#011train-rmse:1.09855#011validation-rmse:1.11739
# [321]#011train-rmse:1.09845#011validation-rmse:1.11740
# [322]#011train-rmse:1.09839#011validation-rmse:1.11746
# [323]#011train-rmse:1.09831#011validation-rmse:1.11738
# [324]#011train-rmse:1.09809#011validation-rmse:1.11723
# [325]#011train-rmse:1.09793#011validation-rmse:1.11713
# [326]#011train-rmse:1.09777#011validation-rmse:1.11708
# [327]#011train-rmse:1.09769#011validation-rmse:1.11713
# [328]#011train-rmse:1.09762#011validation-rmse:1.11708
# [329]#011train-rmse:1.09754#011validation-rmse:1.11706
# [330]#011train-rmse:1.09738#011validation-rmse:1.11700
# [331]#011train-rmse:1.09728#011validation-rmse:1.11690
# [332]#011train-rmse:1.09722#011validation-rmse:1.11686
# [333]#011train-rmse:1.09716#011validation-rmse:1.11685
# [334]#011train-rmse:1.09711#011validation-rmse:1.11685
# [335]#011train-rmse:1.09708#011validation-rmse:1.11688
# [336]#011train-rmse:1.09693#011validation-rmse:1.11678
# [337]#011train-rmse:1.09683#011validation-rmse:1.11673
# [338]#011train-rmse:1.09666#011validation-rmse:1.11659
# [339]#011train-rmse:1.09653#011validation-rmse:1.11654
# [340]#011train-rmse:1.09646#011validation-rmse:1.11657
# [341]#011train-rmse:1.09640#011validation-rmse:1.11652
# [342]#011train-rmse:1.09638#011validation-rmse:1.11650
# [343]#011train-rmse:1.09624#011validation-rmse:1.11648
# [344]#011train-rmse:1.09611#011validation-rmse:1.11642
# [345]#011train-rmse:1.09606#011validation-rmse:1.11640
# [346]#011train-rmse:1.09592#011validation-rmse:1.11634
# [347]#011train-rmse:1.09583#011validation-rmse:1.11630
# [348]#011train-rmse:1.09572#011validation-rmse:1.11629
# [349]#011train-rmse:1.09566#011validation-rmse:1.11626
# [350]#011train-rmse:1.09563#011validation-rmse:1.11630
# [351]#011train-rmse:1.09553#011validation-rmse:1.11625
# [352]#011train-rmse:1.09539#011validation-rmse:1.11618
# [353]#011train-rmse:1.09532#011validation-rmse:1.11615
# [354]#011train-rmse:1.09516#011validation-rmse:1.11616
# [355]#011train-rmse:1.09502#011validation-rmse:1.11613
# [356]#011train-rmse:1.09491#011validation-rmse:1.11613
# [357]#011train-rmse:1.09478#011validation-rmse:1.11604
# [358]#011train-rmse:1.09452#011validation-rmse:1.11596
# [359]#011train-rmse:1.09447#011validation-rmse:1.11595
# [360]#011train-rmse:1.09446#011validation-rmse:1.11594
# [361]#011train-rmse:1.09437#011validation-rmse:1.11593
# [362]#011train-rmse:1.09432#011validation-rmse:1.11591
# [363]#011train-rmse:1.09422#011validation-rmse:1.11593
# [364]#011train-rmse:1.09411#011validation-rmse:1.11588
# [365]#011train-rmse:1.09401#011validation-rmse:1.11585
# [366]#011train-rmse:1.09387#011validation-rmse:1.11579
# [367]#011train-rmse:1.09377#011validation-rmse:1.11574
# [368]#011train-rmse:1.09370#011validation-rmse:1.11570
# [369]#011train-rmse:1.09360#011validation-rmse:1.11566
# [370]#011train-rmse:1.09346#011validation-rmse:1.11558
# [371]#011train-rmse:1.09340#011validation-rmse:1.11558
# [372]#011train-rmse:1.09336#011validation-rmse:1.11559
# [373]#011train-rmse:1.09334#011validation-rmse:1.11560
# [374]#011train-rmse:1.09319#011validation-rmse:1.11542
# [375]#011train-rmse:1.09299#011validation-rmse:1.11532
# [376]#011train-rmse:1.09281#011validation-rmse:1.11521
# [377]#011train-rmse:1.09272#011validation-rmse:1.11521
# [378]#011train-rmse:1.09253#011validation-rmse:1.11517
# [379]#011train-rmse:1.09240#011validation-rmse:1.11508
# [380]#011train-rmse:1.09229#011validation-rmse:1.11509
# [381]#011train-rmse:1.09222#011validation-rmse:1.11511
# [382]#011train-rmse:1.09209#011validation-rmse:1.11500
# [383]#011train-rmse:1.09200#011validation-rmse:1.11503
# [384]#011train-rmse:1.09191#011validation-rmse:1.11496
# [385]#011train-rmse:1.09184#011validation-rmse:1.11497
# [386]#011train-rmse:1.09175#011validation-rmse:1.11500
# [387]#011train-rmse:1.09165#011validation-rmse:1.11499
# [388]#011train-rmse:1.09160#011validation-rmse:1.11502
# [389]#011train-rmse:1.09146#011validation-rmse:1.11500
# [390]#011train-rmse:1.09135#011validation-rmse:1.11496
# [391]#011train-rmse:1.09122#011validation-rmse:1.11486
# [392]#011train-rmse:1.09114#011validation-rmse:1.11481
# [393]#011train-rmse:1.09100#011validation-rmse:1.11475
# [394]#011train-rmse:1.09082#011validation-rmse:1.11468
# [395]#011train-rmse:1.09062#011validation-rmse:1.11453
# [396]#011train-rmse:1.09052#011validation-rmse:1.11447
# [397]#011train-rmse:1.09033#011validation-rmse:1.11450
# [398]#011train-rmse:1.09024#011validation-rmse:1.11449
# [399]#011train-rmse:1.09019#011validation-rmse:1.11448
# [400]#011train-rmse:1.08999#011validation-rmse:1.11429
# [401]#011train-rmse:1.08990#011validation-rmse:1.11422
# [402]#011train-rmse:1.08975#011validation-rmse:1.11422
# [403]#011train-rmse:1.08963#011validation-rmse:1.11413
# [404]#011train-rmse:1.08951#011validation-rmse:1.11413
# [405]#011train-rmse:1.08946#011validation-rmse:1.11415
# [406]#011train-rmse:1.08934#011validation-rmse:1.11413
# [407]#011train-rmse:1.08928#011validation-rmse:1.11416
# [408]#011train-rmse:1.08926#011validation-rmse:1.11416
# [409]#011train-rmse:1.08926#011validation-rmse:1.11416
# [410]#011train-rmse:1.08926#011validation-rmse:1.11416
# [411]#011train-rmse:1.08926#011validation-rmse:1.11416
# [412]#011train-rmse:1.08924#011validation-rmse:1.11416
# [413]#011train-rmse:1.08923#011validation-rmse:1.11416
# [414]#011train-rmse:1.08922#011validation-rmse:1.11417
# [415]#011train-rmse:1.08919#011validation-rmse:1.11417
# [416]#011train-rmse:1.08919#011validation-rmse:1.11417
# [417]#011train-rmse:1.08912#011validation-rmse:1.11411
# [418]#011train-rmse:1.08905#011validation-rmse:1.11406
# [419]#011train-rmse:1.08905#011validation-rmse:1.11407
# [420]#011train-rmse:1.08891#011validation-rmse:1.11400
# [421]#011train-rmse:1.08885#011validation-rmse:1.11396
# [422]#011train-rmse:1.08873#011validation-rmse:1.11390
# [423]#011train-rmse:1.08867#011validation-rmse:1.11390
# [424]#011train-rmse:1.08859#011validation-rmse:1.11389
# [425]#011train-rmse:1.08849#011validation-rmse:1.11383
#
# 2020-11-20 08:30:41 Uploading - Uploading generated training model[426]#011train-rmse:1.08844#011validation-rmse:1.11384
# [427]#011train-rmse:1.08836#011validation-rmse:1.11381
# [428]#011train-rmse:1.08821#011validation-rmse:1.11377
# [429]#011train-rmse:1.08817#011validation-rmse:1.11379
# [430]#011train-rmse:1.08807#011validation-rmse:1.11378
# [431]#011train-rmse:1.08794#011validation-rmse:1.11376
# [432]#011train-rmse:1.08783#011validation-rmse:1.11374
# [433]#011train-rmse:1.08775#011validation-rmse:1.11374
# [434]#011train-rmse:1.08773#011validation-rmse:1.11374
# [435]#011train-rmse:1.08768#011validation-rmse:1.11374
# [436]#011train-rmse:1.08766#011validation-rmse:1.11375
# [437]#011train-rmse:1.08762#011validation-rmse:1.11374
# [438]#011train-rmse:1.08761#011validation-rmse:1.11374
# [439]#011train-rmse:1.08759#011validation-rmse:1.11374
# [440]#011train-rmse:1.08759#011validation-rmse:1.11374
# [441]#011train-rmse:1.08754#011validation-rmse:1.11374
# [442]#011train-rmse:1.08749#011validation-rmse:1.11370
# [443]#011train-rmse:1.08747#011validation-rmse:1.11370
# [444]#011train-rmse:1.08744#011validation-rmse:1.11370
# [445]#011train-rmse:1.08738#011validation-rmse:1.11373
# [446]#011train-rmse:1.08733#011validation-rmse:1.11370
# [447]#011train-rmse:1.08724#011validation-rmse:1.11370
# [448]#011train-rmse:1.08708#011validation-rmse:1.11363
# [449]#011train-rmse:1.08698#011validation-rmse:1.11359
# [450]#011train-rmse:1.08689#011validation-rmse:1.11360
# [451]#011train-rmse:1.08677#011validation-rmse:1.11352
#
# 2020-11-20 08:31:10 Completed - Training job completed
# Training seconds: 191
# Billable seconds: 191

# %% [markdown]
# 352 runden:
# eta 0-35
# alpha 0.3: 1.09971 1.11727
# alpha 0.4: 1.09879 1.11689
# alpha 0.5: 1.09976 1.11694
# alpha 0.6: 1.10047 1.11785
#
# alpha 0.4
# eta 0.35: 1.09879 1.11689
# eta 0.40: 1.09578 1.11635
#
# eta 0.4
# alpha 0.45: 1.09548 1.11630
# alpha 0.50: 1.09582 1.11585
# alpha 0.55: 1.09560 1.11577
#
# eta 0.45 alpha 0.55: 1.09178 1.11506
# eta 0.50 alpha 0.55: 1.08905 1.11538

# %%
#!pip install smdebug
from smdebug.trials import create_trial
s3_output_path = xgboost_debugger.latest_job_debugger_artifacts_path()
trial = create_trial(s3_output_path)
liste = trial.tensor_names()
feature_importance_names = [k for k in liste if 'feature_importance/cover' in k]
feature_importance_col_names = ['isAdult', 'startYear', 'endYear', 'numVotes', 'Crime', 'Romance', 'Thriller', 'Adventure', 'Drama', 'War', 'Documentary', 'Reality-TV', 'Family', 'Fantasy', 'Game-Show', 'Adult', 'History', 'Mystery', 'Musical', 'Animation', 'Music', 'Film-Noir', 'shortGenre', 'Horror', 'Western', 'Biography', 'Comedy', 'Action', 'Sport', 'Talk-Show', 'Sci-Fi', 'News', 'movie', 'short', 'tvEpisode', 'tvMiniSeries', 'tvMovie', 'tvSeries', 'tvShort', 'tvSpecial', 'video', 'videoGame', 'nm0592314', 'nm10514069', 'nm11131030', 'nm11131593', 'nm1915152', 'nm2124199', 'nm2299581', 'nm2699546', 'nm3816718', 'nm4837590', 'nm5181169', 'nm5511980', 'nm6135542', 'nm6419589', 'nm7155068', 'nm7702567', 'nm8062068', 'nm8079243', 'nm8269207', 'nm8409754', 'nm8641187', 'nm8688464', 'nm8713978', 'nm8741892', 'nm9002892', 'nm9099684', 'nm9099685', 'nm9177141', 'nm9325202', 'nm9354107', 'distinct languages', 'distinct regions']
# Out:
# [2020-11-20 08:33:18.872 ip-172-16-29-248:6872 INFO s3_trial.py:42] Loading trial debug-output at path s3://aida-project/team_remote/output/JPC-xgboost-debug-2020-11-20-08-25-38-985/debug-output
# [2020-11-20 08:33:20.479 ip-172-16-29-248:6872 INFO trial.py:198] Training has ended, will refresh one final time in 1 sec.
# [2020-11-20 08:33:21.498 ip-172-16-29-248:6872 INFO trial.py:210] Loaded all steps

# %%
# change of feature weight over time
feat_dict_step={}
feat_dict_step={}
start=50
step = 50
ende=450
for i,f in enumerate(feature_importance_names):
    tmp=[]
    index=int(f.split('f')[2])
    lbl=feature_importance_col_names[index]
    #print(trial.tensor(f).values())
    for j in range(start, ende+1,step):
        try:
            tmp.append(trial.tensor(f).values()[j][0])
        except:
            tmp.append(0)
    
    feat_dict_step[lbl]=tmp
    #print(i,tmp)
    #break
"""
    try:
        feat_dict_start[feature_importance_col_names[index]]=trial.tensor(f).values()[start][0]
    except:
        feat_dict_start[feature_importance_col_names[index]]=0
    break
"""
print(feat_dict_step)
# Out:
# {'isAdult': [0.017400485750353543, 0.007812673768787203, 0.010026915727241638, 0.009738880707965332, 0.010759561269090251, 0.009419028827357394, 0.009262954814734688, 0.008542308594109937, 0.008875305417008544], 'startYear': [0.003692035361792439, 0.0019939033115662884, 0.0020107585322551307, 0.0019549146990406, 0.0019580305981567844, 0.001923102764916526, 0.0019973915770896402, 0.0020159951038857065, 0.0020116895616449073], 'Documentary': [0.004028041187189048, 0.0018034457065453401, 0.001852595878209304, 0.0020825060055045283, 0.0019345748680287625, 0.0020731558636263537, 0.002045104008734823, 0.0018734556273756143, 0.0018199283191005053], 'Reality-TV': [0.005833605437310144, 0.003431734743958148, 0.003366321936366476, 0.0033118698130683143, 0.0034330024135922265, 0.0035361726112496206, 0.003322907198026142, 0.0033344436039134426, 0.003490829914133306], 'Family': [0.007033250471938261, 0.003171479542425905, 0.0027261193814426643, 0.0028789422463786707, 0.002646734893118705, 0.0026405108681481623, 0.0025741485026936016, 0.0027149540286033865, 0.002706508697744623], 'Fantasy': [0.006231685205591649, 0.004173661260916304, 0.0028373995068951773, 0.0026139044537088333, 0.002744325251771907, 0.0027651199858634424, 0.002655345943938196, 0.0027800826611418398, 0.002903677592464471], 'Game-Show': [0.01781091022655993, 0.0060831670448741335, 0.006136039592947951, 0.006052161347232116, 0.005922493390574468, 0.006218059672614564, 0.005837466140076735, 0.005911185772556268, 0.005758958415027745], 'Adult': [0.004526312499684301, 0.005378109547550215, 0.006202274869147903, 0.006865694133858299, 0.0067942661189510116, 0.0064639218334534825, 0.007101634073006332, 0.007299770410371563, 0.007483674186271348], 'History': [0.015160157290176115, 0.004396357955547077, 0.004046684324961075, 0.004158009307498124, 0.003627546520969327, 0.004096017471588352, 0.0041177301253205725, 0.003782694727459776, 0.003877800722277818], 'Mystery': [0.011915573394332366, 0.00479337292752557, 0.003906673145818338, 0.0038354246038139693, 0.0036547319760112515, 0.003229415728261193, 0.0031528110108982967, 0.003337116183349678, 0.0034241629314392076], 'Musical': [0.004023513269138275, 0.00301081211530269, 0.003674744628009437, 0.0034128039556753672, 0.0033513767747997765, 0.0032778764397156743, 0.0033927116761398464, 0.003303501893915807, 0.003532192486376683], 'Animation': [0.0038041095110744757, 0.0022437618454386327, 0.0018902490366047304, 0.001824087870350604, 0.0018328480595194024, 0.0018298688862180398, 0.0019094933883360237, 0.002032907806485657, 0.0020972343420711755], 'endYear': [0.006818272634869437, 0.00424844126032608, 0.004877371009337711, 0.0048766418273903465, 0.004856131708357763, 0.004782827333354637, 0.004916179216213971, 0.004885648407650847, 0.004908698825851242], 'Music': [0.004344272726889946, 0.002486324429792212, 0.0032805191565800683, 0.003116266288526908, 0.0030798991480340374, 0.0028369983944529368, 0.0028512471146704666, 0.0028231517699275, 0.0027579977994301864], 'Film-Noir': [0, 0.028357983406454505, 0.028748008588714614, 0.02894206861541846, 0.029222340279732757, 0.02948556853190029, 0.029529686624288523, 0.029650463171839503, 0.02150370428300002], 'shortGenre': [0.002386261234338111, 0.0018723867618475644, 0.002838164035374162, 0.002708730166594227, 0.0025484091026374755, 0.002841355755486477, 0.00297628407709048, 0.002803786645794261, 0.0025986684966445035], 'Horror': [0.007271814765613457, 0.003577980725106861, 0.003257871315515277, 0.0031043567218558958, 0.003091299932855753, 0.003353828068229545, 0.003169446154621393, 0.0031824350297711243, 0.0032572561708823777], 'Western': [0.032682826335168814, 0.015949956142933378, 0.016227314311936275, 0.01706258704418146, 0.015176198527193527, 0.012047573626661442, 0.013458742316811705, 0.013379957327005502, 0.01307564688826408], 'Biography': [0.007290901546231002, 0.0029932573021393552, 0.0028120483911562447, 0.003273123998403495, 0.0031041372402084706, 0.0030364551540751337, 0.00311682339797 ...

# %%
import matplotlib.pyplot as plt
#plt.bar(*zip(*feat_dict_step.items()))
xval=[i for i in range(start,ende+1,step)]
val_high = 0
lbl_high = ""
fig,ax = plt.subplots(figsize=(10,10))
for k,yval in feat_dict_step.items():
    #print(k,yval)
    #break
    if yval[-1] > val_high:
        val_high = yval[-1]
        lbl_high = k
    plt.plot(xval,yval)
    
ax.text(xval[-1]-20,val_high+0.001,lbl_high.replace(" ","\n"),horizontalalignment='center',fontsize=20)
plt.title(f'Feature Importances', fontsize=20)
plt.xlabel('runs', fontsize=20)
plt.ylabel('share', fontsize=20)    

save_it=True
if save_it == True:
    from datetime import datetime

    now = datetime.now() # current date and time
    time = now.strftime("%m-%d-%Y-%H-%M-%S")
    filename='Feature_importance by iteraton-'+time
    plt.savefig(filename, dpi=None, facecolor='w', edgecolor='w',
        orientation='portrait')
plt.show()

# %%
#!pip install smdebug
from smdebug.trials import create_trial
s3_output_path = xgboost_debugger.latest_job_debugger_artifacts_path()
trial = create_trial(s3_output_path)
# Out:
# [2020-11-20 08:41:52.846 ip-172-16-29-248:6872 INFO s3_trial.py:42] Loading trial debug-output at path s3://aida-project/team_remote/output/JPC-xgboost-debug-2020-11-20-08-25-38-985/debug-output

# %%
#trial.tensor_names()

# %%
trial.tensor("feature_importance/cover/f0").values()
# Out:
# [2020-11-20 08:41:55.958 ip-172-16-29-248:6872 INFO trial.py:198] Training has ended, will refresh one final time in 1 sec.
# [2020-11-20 08:41:56.980 ip-172-16-29-248:6872 INFO trial.py:210] Loaded all steps
# {50: array([0.01740049]),
#  100: array([0.00781267]),
#  150: array([0.01002692]),
#  200: array([0.00973888]),
#  250: array([0.01075956]),
#  300: array([0.00941903]),
#  350: array([0.00926295]),
#  400: array([0.00854231]),
#  450: array([0.00887531])}

# %%
liste = trial.tensor_names()

# %%
#[k for k in lst if 'ab' in k]
feature_importance_names = [k for k in liste if 'feature_importance/cover' in k]
#feature_importance_col_names = ['isAdult', 'startYear', 'endYear', 'numVotes', 'Crime', 'Romance', 'Thriller', 'Adventure', 'Drama', 'War', 'Documentary', 'Reality-TV', 'Family', 'Fantasy', 'Game-Show', 'Adult', 'History', 'Mystery', 'Musical', 'Animation', 'Music', 'Film-Noir', 'shortGenre', 'Horror', 'Western', 'Biography', 'Comedy', 'Action', 'Sport', 'Talk-Show', 'Sci-Fi', 'News', 'movie', 'short', 'tvEpisode', 'tvMiniSeries', 'tvMovie', 'tvSeries', 'tvShort', 'tvSpecial', 'video', 'videoGame', 'distinct languages', 'distinct regions']
feature_importance_weight = [k for k in liste if 'feature_importance/weight' in k]

# %%
feat_dict_start={}
feat_dict_ende={}
start=50
ende=450
for i,f in enumerate(feature_importance_names):
    #print(feature_importance_col_names[i],"\t\t",end='')
    #print(trial.tensor(f).values())
    #print(trial.tensor(f).values()[40][0])
    index=int(f.split('f')[2])
    try:
        feat_dict_start[feature_importance_col_names[index]]=trial.tensor(f).values()[start][0]
    except:
        feat_dict_start[feature_importance_col_names[index]]=0
    #break
print(feat_dict_start)
for i,f in enumerate(feature_importance_names):
    index=int(f.split('f')[2])
    try:
        feat_dict_ende[feature_importance_col_names[index]]=trial.tensor(f).values()[ende][0]
    except:
        feat_dict_ende[feature_importance_col_names[index]]=0
print(feat_dict_ende)
# Out:
# {'isAdult': 0.017400485750353543, 'startYear': 0.003692035361792439, 'Documentary': 0.004028041187189048, 'Reality-TV': 0.005833605437310144, 'Family': 0.007033250471938261, 'Fantasy': 0.006231685205591649, 'Game-Show': 0.01781091022655993, 'Adult': 0.004526312499684301, 'History': 0.015160157290176115, 'Mystery': 0.011915573394332366, 'Musical': 0.004023513269138275, 'Animation': 0.0038041095110744757, 'endYear': 0.006818272634869437, 'Music': 0.004344272726889946, 'Film-Noir': 0, 'shortGenre': 0.002386261234338111, 'Horror': 0.007271814765613457, 'Western': 0.032682826335168814, 'Biography': 0.007290901546231002, 'Comedy': 0.002431881665323869, 'Action': 0.0047539229595918156, 'Sport': 0.01200797455732382, 'Talk-Show': 0.009832020154902605, 'numVotes': 0.004534795034658472, 'Sci-Fi': 0.007195950274088363, 'News': 0.01940263360822286, 'movie': 0.00819653644251482, 'short': 0.0083428297362326, 'tvEpisode': 0.0063698751303402105, 'tvMiniSeries': 0.030462336960437854, 'tvMovie': 0.0065923756282059804, 'tvSeries': 0.005589923550306945, 'tvShort': 0.028333267808321953, 'tvSpecial': 0.013318160302563197, 'Crime': 0.012515440789674632, 'video': 0.003841207518038005, 'videoGame': 0.02422622178349852, 'nm0592314': 0.056615170011480156, 'nm10514069': 0, 'nm11131030': 0.05661312946004215, 'nm11131593': 0, 'nm1915152': 0.05661495891995209, 'nm2699546': 0.05661509964763747, 'Romance': 0.005852174869301008, 'nm3816718': 0.05661502928379478, 'nm4837590': 0.05661509964763747, 'nm5181169': 0, 'nm5511980': 0, 'nm6135542': 0, 'nm6419589': 0.05661502928379478, 'nm7155068': 0, 'nm7702567': 0, 'nm8062068': 0, 'nm8079243': 0.056615170011480156, 'Thriller': 0.007707683473806485, 'nm8269207': 0, 'nm8409754': 0, 'nm8641187': 0, 'nm8688464': 0, 'nm8713978': 0, 'nm8741892': 0, 'nm9099684': 0.0565823100969439, 'nm9099685': 0.05658216936925852, 'nm9177141': 0, 'Adventure': 0.005811554049896173, 'nm9325202': 0, 'nm9354107': 0, 'distinct languages': 0.007159444375307341, 'distinct regions': 0.005058913469096811, 'Drama': 0.004467976723418126, 'War': 0.027657704554654664}
# {'isAdult': 0.008875305417008544, 'startYear': 0.0020116895616449073, 'Documentary': 0.0018199283191005053, 'Reality-TV': 0.003490829914133306, 'Family': 0.002706508697744623, 'Fantasy': 0.002903677592464471, 'Game-Show': 0.005758958415027745, 'Adult': 0.007483674186271348, 'History': 0.003877800722277818, 'Mystery': 0.0034241629314392076, 'Musical': 0.003532192486376683, 'Animation': 0.0020972343420711755, 'endYear': 0.004908698825851242, 'Music': 0.0027579977994301864, 'Film-Noir': 0.02150370428300002, 'shortGenre': 0.0025986684966445035, 'Horror': 0.0032572561708823777, 'Western': 0.01307564688826408, 'Biography': 0.0034021598961913187, 'Comedy': 0.0013211628761504528, 'Action': 0.002003233637757256, 'Sport': 0.004470015362506387, 'Talk-Show': 0.0041610367935541225, 'numVotes': 0.0039047033529426866, 'Sci-Fi': 0.003212682704013415, 'News': 0.005754691330280356, 'movie': 0.0025158551352626127, 'short': 0.003929985811564993, 'tvEpisode': 0.0016681371179894625, 'tvMiniSeries': 0.005099122175865793, 'tvMovie': 0.0035253053948398005, 'tvSeries': 0.0024741090029239514, 'tvShort': 0.009843305087140798, 'tvSpecial': 0.005870765226093246, 'Crime': 0.0031782911616902265, 'video': 0.0029376576493004925, 'videoGame': 0.008060104285883852, 'nm0592314': 0.029852982211729908, 'nm10514069': 0.02986392411353372, 'nm11131030': 0.029827973210931377, 'nm11131593': 0.029862477812854313, 'nm1915152': 0.029863981025279873, 'nm2699546': 0.02948547195978001, 'Romance': 0.0028724687648334813, 'nm3816718': 0.029837178067265654, 'nm4837590': 0.02985294509537372, 'nm5181169': 0.02977456153716699, 'nm5511980': 0.02977404397020017, 'nm6135542': 0.029862669580694612, 'nm6419589': 0.029754256828313137, 'nm7155068': 0.029741527980160918, 'nm7702567': 0.02986294795336601, 'nm8062068': 0.0298638016295583, 'nm8079243': 0.029812715604811975, 'Thriller': 0.003497123110950593, 'nm8269207': 0.029750069160697667, 'nm8409754': 0.029863973292705664, 'nm8641187': 0.029722540489547727, 'nm8688464': 0.029805425554781682, 'nm8713978': 0.029795668371718438, 'nm8741892': 0.029791231199708605, 'nm9099684': 0.029769470410310063, 'nm9099685': 0.02976939617759769, 'nm9177141': 0.02979119408335242, 'Adventure': 0.0026714213301457577, 'nm9325202': 0.029840344092448373, 'nm9354107': 0.029755875219272573, 'distinct languages': 0.0030951831396143414, 'distinct regions': 0.0028199039663973254, 'Drama': 0.0018238240642724963, 'War': 0.005255169939040462}

# %%
feat_weight_dict={}
for i,f in enumerate(feature_importance_weight):
    index=int(f.split('f')[2])
    print(feature_importance_col_names[index],"\t\t",end='')
    print("i,f:",str(i)," ", f)
    print(trial.tensor(f).values())
    #print(trial.tensor(f).values()[40][0])
    feat_weight_dict[feature_importance_col_names[index]]=trial.tensor(f).values()[ende][0]
    #break
#print(feat_weight_dict)
# Out:
# isAdult 		i,f: 0   feature_importance/weight/f0
# {50: array([0.00517799]), 100: array([0.00417851]), 150: array([0.0036921]), 200: array([0.00322553]), 250: array([0.00286553]), 300: array([0.00263158]), 350: array([0.00274806])}
# startYear 		i,f: 1   feature_importance/weight/f1
# {0: array([0.23728814]), 50: array([0.17702265]), 100: array([0.18251713]), 150: array([0.18348624]), 200: array([0.18292165]), 250: array([0.18475814]), 300: array([0.18655606]), 350: array([0.18623025])}
# Documentary 		i,f: 2   feature_importance/weight/f10
# {0: array([0.05084746]), 50: array([0.02071197]), 100: array([0.01938827]), 150: array([0.01834862]), 200: array([0.01833461]), 250: array([0.01767074]), 300: array([0.01767735]), 350: array([0.01746982])}
# Reality-TV 		i,f: 3   feature_importance/weight/f11
# {0: array([0.05084746]), 50: array([0.01262136]), 100: array([0.0153769]), 150: array([0.01376147]), 200: array([0.01298701]), 250: array([0.01234905]), 300: array([0.01229977]), 350: array([0.01290608])}
# Family 		i,f: 4   feature_importance/weight/f12
# {50: array([0.01877023]), 100: array([0.01838543]), 150: array([0.01801298]), 200: array([0.01850437]), 250: array([0.01896705]), 300: array([0.01864989]), 350: array([0.01805869])}
# Fantasy 		i,f: 5   feature_importance/weight/f13
# {50: array([0.00744337]), 100: array([0.01019555]), 150: array([0.01219512]), 200: array([0.01264748]), 250: array([0.0124855]), 300: array([0.01212815]), 350: array([0.01177741])}
# Game-Show 		i,f: 6   feature_importance/weight/f14
# {0: array([0.01694915]), 50: array([0.00841424]), 100: array([0.00869129]), 150: array([0.00816738]), 200: array([0.00763942]), 250: array([0.00818721]), 300: array([0.00789474]), 350: array([0.00819511])}
# Adult 		i,f: 7   feature_importance/weight/f15
# {50: array([0.00355987]), 100: array([0.00317566]), 150: array([0.00279705]), 200: array([0.00297089]), 250: array([0.00272907]), 300: array([0.0028032]), 350: array([0.00279713])}
# History 		i,f: 8   feature_importance/weight/f16
# {50: array([0.00485437]), 100: array([0.00618419]), 150: array([0.00626538]), 200: array([0.00619642]), 250: array([0.00607218]), 300: array([0.00646453]), 350: array([0.00623221])}
# Mystery 		i,f: 9   feature_importance/weight/f17
# {50: array([0.00873786]), 100: array([0.00902557]), 150: array([0.00906243]), 200: array([0.00959172]), 250: array([0.00975643]), 300: array([0.00955378]), 350: array([0.00986358])}
# Musical 		i,f: 10   feature_importance/weight/f18
# {50: array([0.00647249]), 100: array([0.00601705]), 150: array([0.00548221]), 200: array([0.00517783]), 250: array([0.00498056]), 300: array([0.0048627]), 350: array([0.00495633])}
# Animation 		i,f: 11   feature_importance/weight/f19
# {0: array([0.01694915]), 50: array([0.0223301]), 100: array([0.01938827]), 150: array([0.01935556]), 200: array([0.01765555]), 250: array([0.01726138]), 300: array([0.01676201]), 350: array([0.01648837])}
# endYear 		i,f: 12   feature_importance/weight/f2
# {0: array([0.01694915]), 50: array([0.04563107]), 100: array([0.0469664]), 150: array([0.05292012]), 200: array([0.05440964]), 250: array([0.05410384]), 300: array([0.05434783]), 350: array([0.05437236])}
# Music 		i,f: 13   feature_importance/weight/f20
# {50: array([0.02038835]), 100: array([0.01888685]), 150: array([0.01655851]), 200: array([0.01578813]), 250: array([0.01562393]), 300: array([0.01533181]), 350: array([0.0153597])}
# Film-Noir 		i,f: 14   feature_importance/weight/f21
# {100: array([0.00033428]), 150: array([0.00044753]), 200: array([0.00042441]), 250: array([0.00034113]), 300: array([0.00028604]), 350: array([0.00024536])}
# shortGenre 		i,f: 15   feature_importance/weight/f22
# {50: array([0.01391586]), 100: array([0.01337122]), 150: array([0.01320206]), 200: array([0.01247772]), 250: array([0.01289486]), 300: array([0.0125286]), 350: array([0.01320051])}
# Horror 		i,f: 16   feature_importance/weight/f23
# {0: array([0.08474576]), 50: array([0.02297735]), 100: array([0.01855257]), 150: array([0.0179011]), 200: array([0.01646719]), 250: array([0.01521457]), 300: array([0.01481693]), 350: array([0.01452547])}
# Western 		i,f: 17   feature_importance/weight/f24
# {50: array([0.00453074]), 100: array([0.00367709]), 150: array([0.00358022]), 200: array([0.00356506]), 250: array([0.00341134]), 300: array([0.00320366]), 350: array([0.00328786])}
# Biography 		i,f: 18   feature_importance/weight/f25
# {0: array([0.01694915]), 50: array([0.00582524]), 100: array([0.00584991]), 150: array([0.00559409]), 200: array([0.00568712]), 250: array([0.0055946]), 300: array([0.0055492]), 350: array([0.00559427])}
# Comedy 		i,f: 19   feature_importance/weight/f26
# {50: array([0.03559871]), 100: array([0.03142236]), 150: array([0.03412397]), 200: array([0.03471692]), 250: array([0.03411339]), 300: array([0.03323799]), 350: array([0.03263323])}
# Action 		i,f: 20   feature_importance/weight/f27
# {50: array([0.0223301]), 100: array([0.02156109]), 150: array([0.02181696]), 200: array([0.02130549]), 250: array([0.02108208]), 300: array([0.01956522]), 350: array([0.01923643])}
# Sport 		i,f: 21   feature_importance/weight/f28
# {50: array([0.01132686]), 100: array([0.01086411]), 150: array([0.0098456]), 200: array([0.00840336]), 250: array([0.00818721]), 300: array([0.00800915]), 350: array([0.00740995])}
# Talk-Show 		i,f: 22   feature_importance/weight/f29
# {0: array([0.01694915]), 50: array([0.01294498]), 100: array([0.01169982]), 150: array([0.01197136]), 200: array([0.01171378]), 250: array([0.01125742]), 300: array([0.01092677]), 350: array([0.01055059])}
# numVotes 		i,f: 23   feature_importance/weight/f3
# {0: array([0.23728814]), 50: array([0.20614887]), 100: array([0.21310379]), 150: array([0.21402998]), 200: array([0.22154316]), 250: array([0.22808215]), 300: array([0.23323799]), 350: array([0.23721661])}
# Sci-Fi 		i,f: 24   feature_importance/weight/f30
# {50: array([0.01067961]), 100: array([0.01153268]), 150: array([0.01062878]), 200: array([0.01078007]), 250: array([0.0104387]), 300: array([0.01024027]), 350: array([0.01055059])}
# News 		i,f: 25   feature_importance/weight/f31
# {0: array([0.01694915]), 50: array([0.00744337]), 100: array([0.00584991]), 150: array([0.00760797]), 200: array([0.0067906]), 250: array([0.00682268]), 300: array([0.00703661]), 350: array([0.00701737])}
# movie 		i,f: 26   feature_importance/weight/f32
# {0: array([0.01694915]), 50: array([0.01521036]), 100: array([0.01571118]), 150: array([0.01655851]), 200: array([0.01655208]), 250: array([0.01569216]), 300: array([0.01561785]), 350: array([0.0148199])}
# short 		i,f: 27   feature_importance/weight/f33
# {50: array([0.00873786]), 100: array([0.00902557]), 150: array([0.00872678]), 200: array([0.00806383]), 250: array([0.00730027]), 300: array([0.00715103]), 350: array([0.00682108])}
# tvEpisode 		i,f: 28   feature_importance/weight/f34
# {0: array([0.01694915]), 50: array([0.02653722]), 100: array([0.02590674]), 150: array([0.02383083]), 200: array([0.02215432]), 250: array([0.02053626]), 300: array([0.01973684]), 350: array([0.01884385])}
# tvMiniSeries 		i,f: 29   feature_importance/weight/f35
# {50: array([0.0012945]), 100: array([0.00233996]), 150: array([0.00257328]), 200: array([0.00271624]), 250: array([0.0027973]), 300: array([0.00337529]), 350: array([0.00328786])}
# tvMovie 		i,f: 30   feature_importance/weight/f36
# {0: array([0.01694915]), 50: array([0.00711974]), 100: array([0.00869129]), 150: array([0.00783173]), 200: array([0.00755454]), 250: array([0.00757317]), 300: array([0.00715103]), 350: array([0.00716459])}
# tvSeries 		i,f: 31   feature_importance/weight/f37
# {50: array([0.01165049]), 100: array([0.01002841]), 150: array([0.01040501]), 200: array([0.01001613]), 250: array([0.01023402]), 300: array([0.00995423]), 350: array([0.01025616])}
# tvShort 		i,f: 32   feature_importance/weight/f38
# {50: array([0.00097087]), 100: array([0.00200568]), 150: array([0.00179011]), 200: array([0.00178253]), 250: array([0.00170567]), 300: array([0.00160183]), 350: array([0.00166847])}
# tvSpecial 		i,f: 33   feature_importance/weight/f39
# {50: array([0.00550162]), 100: array([0.00551563]), 150: array([0.00514657]), 200: array([0.00500806]), 250: array([0.00491233]), 300: array([0.00474828]), 350: array([0.00480911])}
# Crime 		i,f: 34   feature_importance/weight/f4
# {50: array([0.01165049]), 100: array([0.01236838]), 150: array([0.01253077]), 200: array([0.01358119]), 250: array([0.01391826]), 300: array([0.01338673]), 350: array([0.01374031])}
# video 		i,f: 35   feature_importance/weight/f40
# {0: array([0.01694915]), 50: array([0.01521036]), 100: array([0.01504262]), 150: array([0.01488029]), 200: array([0.01324166]), 250: array([0.01289486]), 300: array([0.01264302]), 350: array([0.01261164])}
# videoGame 		i,f: 36   feature_importance/weight/f41
# {50: array([0.00226537]), 100: array([0.00233996]), 150: array([0.0024614]), 200: array([0.00263136]), 250: array([0.00266084]), 300: array([0.00286041]), 350: array([0.00289528])}
# distinct languages 		i,f: 37   feature_importance/weight/f42
# {0: array([0.06779661]), 50: array([0.03365696]), 100: array([0.03259234]), 150: array([0.03155068]), 200: array([0.03234021]), 250: array([0.03186191]), 300: array([0.03112128]), 350: array([0.03076848])}
# distinct regions 		i,f: 38   feature_importance/weight/f43
# {0: array([0.06779661]), 50: array([0.06472492]), 100: array([0.06551897]), 150: array([0.06455583]), 200: array([0.06629318]), 250: array([0.06583885]), 300: array([0.06767735]), 350: array([0.0680636])}
# Romance 		i,f: 39   feature_importance/weight/f5
# {50: array([0.01488673]), 100: array([0.01604546]), 150: array([0.01532781]), 200: array([0.01578813]), 250: array([0.01671556]), 300: array([0.0166476]), 350: array([0.01658651])}
# Thriller 		i,f: 40   feature_importance/weight/f6
# {50: array([0.00841424]), 100: array([0.00919271]), 150: array([0.00917431]), 200: array([0.01001613]), 250: array([0.01023402]), 300: array([0.01001144]), 350: array([0.009471])}
# Adventure 		i,f: 41   feature_importance/weight/f7
# {50: array([0.02135922]), 100: array([0.01738258]), 150: array([0.01756545]), 200: array([0.01689161]), 250: array([0.01657911]), 300: array([0.01601831]), 350: array([0.01624301])}
# Drama 		i,f: 42   feature_importance/weight/f8
# {0: array([0.03389831]), 50: array([0.03300971]), 100: array([0.03209092]), 150: array([0.03155068]), 200: array([0.03038791]), 250: array([0.02988333]), 300: array([0.02957666]), 350: array([0.02914908])}
# War 		i,f: 43   feature_importance/weight/f9
# {50: array([0.00194175]), 100: array([0.00200568]), 150: array([0.00268516]), 200: array([0.00305577]), 250: array([0.00341134]), 300: array([0.00411899]), 350: array([0.00387673])}

# %%
import matplotlib.pyplot as plt
plt.bar(range(len(feat_dict_start)),list(feat_dict_start.values()))
plt.title(f"Feature_importances (after {start} training steps)", fontsize=20)
plt.show()
plt.bar(range(len(feat_dict_ende)),list(feat_dict_ende.values()))
plt.title(f"Feature_importances (after {ende} training steps)", fontsize=20)
# Out:
# Text(0.5, 1.0, 'Feature_importances (after 450 training steps)')

# %%
plt.bar(range(len(feat_weight_dict)),list(feat_weight_dict.values()))
plt.title("Feature_importances_weight", fontsize=20)
# Out:
# Text(0.5, 1.0, 'Feature_importances_weight')

# %%
import pandas as pd

# %%
from datetime import datetime

now = datetime.now() # current date and time
time = now.strftime("%m-%d-%Y-%H-%M-%S")
#print(time)

dict = feat_dict_ende

fig,ax = plt.subplots(figsize=(20,10))

#pd.DataFrame(feat_dict, index=['quantity']).plot(kind='bar',ax=ax,use_index=False, legend=False,width=1.4)
plt.bar(*zip(*dict.items()))
plt.title(f'Feature Importances ({ende} runs)', fontsize=20)
plt.xlabel('Feature', fontsize=20)
plt.ylabel('share', fontsize=20)
plt.xticks(ticks=[])
threshold=0.01
pad=0.001
i=0
for k,v in dict.items():
    if v > threshold:
        ax.text(i,v+pad,k.replace(" ","\n"),horizontalalignment='center',fontsize=20)
    #reak
    i +=1
#plt.xlim([0,10])
#plt.ylim([0,10])
#plt.plot([0,10],[0,10], c='red')

#plt.show()
save_it=True
if save_it == True:
    filename='Feature_importance_1-'+time
    plt.savefig(filename, dpi=None, facecolor='w', edgecolor='w',
        orientation='portrait')
plt.show()

# %%
sum=0
for k,v in feat_dict_ende.items():
    sum=sum+v
print(round(sum,7))
# Out:
# 1.0

# %% [markdown]
# # Deploy Model

# %% [markdown]
# ## Deploy

# %%
# Deploy  model to an endpoint

xgb_predictor = xgboost_debugger.deploy(
    initial_instance_count = 1, 
    instance_type = 'ml.t2.medium')
# Out:
# Parameter image will be renamed to image_uri in SageMaker Python SDK v2.
# -----------------!

# %% [markdown]
# ## Configure Predictor

# %%
# Configure the predictor's serializer and deserializer

# INSERT CODE HERE

from sagemaker.predictor import csv_serializer, json_deserializer

xgb_predictor.content_type = "text/csv"
xgb_predictor.serializer = csv_serializer
xgb_predictor.deserializer = json_deserializer

# %% [markdown]
# # Display Endpoint

# %%
xgb_predictor.endpoint
# Out:
# 'JPC-xgboost-debug-2020-11-20-08-25-38-985'

# %% [markdown]
# # Prediction

# %%
# carefully just one prediction
import pandas as pd
import matplotlib.pyplot as plt

#col_names = ['averageRating', 'isAdult', 'startYear', 'endYear', 'numVotes', 'Crime', 'Romance', 'Thriller', 'Adventure', 'Drama', 'War', 'Documentary', 'Reality-TV', 'Family', 'Fantasy', 'Game-Show', 'Adult', 'History', 'Mystery', 'Musical', 'Animation', 'Music', 'Film-Noir', 'shortGenre', 'Horror', 'Western', 'Biography', 'Comedy', 'Action', 'Sport', 'Talk-Show', 'Sci-Fi', 'News', 'movie', 'short', 'tvEpisode', 'tvMiniSeries', 'tvMovie', 'tvSeries', 'tvShort', 'tvSpecial', 'video', 'videoGame', 'distinct languages', 'distinct regions']
test = pd.read_csv(f"{s3_path}{test_source_path}/{test_source_name}", header=0, index_col=False, names=feature_importance_col_names)
prediction=[]
for i in range(test.shape[0]):
    prediction.append(xgb_predictor.predict(test.iloc[i, 1:]))
    if i % 5000 == 0:
        print(i)
    #     print(prediction)
    #     print(test.iloc[i,0])
#print(prediction) 

#plt.scatter(test.iloc[:,0], prediction)
# Out:
# 0
# 5000
# 10000
# 15000
# 20000
# 25000
# 30000
# 35000
# 40000
# 45000
# 50000
# 55000
# 60000
# 65000
# 70000
# 75000
# 80000
# 85000
# 90000
# 95000

# %%
from datetime import datetime

now = datetime.now() # current date and time
time = now.strftime("%m-%d-%Y-%H-%M-%S")
print(time)



fig = plt.subplots(figsize=(10,10))
plt.scatter(test.iloc[:,0], prediction,marker='.',alpha=0.3)
plt.title(f'Prediction incl names (train data) {ende} steps', fontsize=20)
plt.xlabel('original value')
plt.ylabel('predicted value')
plt.xlim([0,10])
plt.ylim([0,10])
plt.plot([0,10],[0,10], c='red')

#plt.show()
filename='Prediction-'+time
plt.savefig(filename, dpi=None, facecolor='w', edgecolor='w',
        orientation='portrait')
# Out:
# 11-20-2020-09-24-52

# %%
# Out:
# 11-18-2020-14-55-10
