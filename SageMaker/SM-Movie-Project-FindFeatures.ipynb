# %% [markdown]
# # Initialize

# %% [markdown]
# ## ASW session

# %%
import boto3

session = boto3.Session()
s3 = session.resource('s3')

# %% [markdown]
# ## SageMaker Session

# %%
import sagemaker

sage_session = sagemaker.Session()

# %% [markdown]
# # Define Globals

# %%
# bucket name
bucket = 'aida-project'

# path for s3_input
s3_path = f"s3://{bucket}/"

## define source files
# TRAIN source file
train_source_path = 'team_remote'
train_source_name = 'title-train.csv'
#train_source_name = 'title-valid.csv'       # for testing; remove later


# VALID source file
valid_source_path = 'team_remote'
valid_source_name = 'title-valid.csv'
#valid_source_name = 'title-test.csv'       # for testing; remove later

# TEST source file
test_source_path = 'team_remote'
test_source_name = 'title-test.csv'

# output for result
output_path ='team_remote'
output_location = f'{s3_path}{output_path}/output'

# %%
print(output_location)
# Out:
# s3://aida-project/team_remote/output

# %%
# Create pointers to the S3 train and test datasets

from sagemaker import s3_input

# print(f"{s3_path}{train_source_path}/{train_source_name}")
# print(f"{s3_path}{valid_source_path}/{valid_source_name}")
# print(f"{s3_path}{test_source_path}/{test_source_name}")
s3_input_train = sagemaker.session.s3_input(s3_data=f"{s3_path}{train_source_path}/{train_source_name}", content_type="text/csv")
s3_input_valid = sagemaker.session.s3_input(s3_data=f"{s3_path}{valid_source_path}/{valid_source_name}", content_type="text/csv")
s3_input_test = sagemaker.session.s3_input(s3_data=f"{s3_path}{test_source_path}/{test_source_name}", content_type="text/csv")
# Out:
# 's3_input' class will be renamed to 'TrainingInput' in SageMaker Python SDK v2.
# 's3_input' class will be renamed to 'TrainingInput' in SageMaker Python SDK v2.
# 's3_input' class will be renamed to 'TrainingInput' in SageMaker Python SDK v2.

# %%
role = sagemaker.get_execution_role()

# %% [markdown]
# # Define Model

# %%
# finde pre-defined models here:
# https://docs.aws.amazon.com/sagemaker/latest/dg/sagemaker-algo-docker-registry-paths.html

# Create an XGBoost Estimator

# estimator call
# <ecr_path>/sagemaker-xgboost:1.2-1
    
ecr_path = "492215442770.dkr.ecr.eu-central-1.amazonaws.com"
xgboost_estimator = f"{ecr_path}/sagemaker-xgboost:1.0-1-cpu-py3"

# ecr_path = "664544806723.dkr.ecr.eu-central-1.amazonaws.com"
# knn_estimator = f"{ecr_path}/knn:latest"

# %%
xgboost = sagemaker.estimator.Estimator(xgboost_estimator,
                              role,
                              train_instance_count=1,
                              train_instance_type="ml.m5.4xlarge",
                              output_path=output_location,
                              sagemaker_session=sage_session,
                              base_job_name="JPC-xgboost")
# Out:
# Parameter image_name will be renamed to image_uri in SageMaker Python SDK v2.

# %%
# Select the your specific hyperparameters (Optional)
# https://docs.aws.amazon.com/sagemaker/latest/dg/xgboost_hyperparameters.html
# https://github.com/dmlc/xgboost/blob/master/doc/parameter.rst#learning-task-parameters 

xgboost.set_hyperparameters(
    eta=.35,
    num_round=252,                     # required parameter!
    objective = 'reg:linear',
    )

# %%
from sagemaker.debugger import rule_configs, Rule, DebuggerHookConfig, CollectionConfig
from sagemaker.estimator import Estimator 
save_interval = 50
xgboost_debugger = Estimator( role=role, 
                             base_job_name="JPC-xgboost-debug", 
                             train_instance_count=1, 
                             train_instance_type='ml.m5.4xlarge', 
                             image_name=xgboost_estimator, 
                             #hyperparameters=hyperparameters, 
                             train_max_run=1800, 
                             debugger_hook_config=DebuggerHookConfig( s3_output_path=output_location, # Required 
                             collection_configs=[ CollectionConfig( name="feature_importance", parameters={ "save_interval": str(save_interval) } ), ], ), 
                              rules=[ Rule.sagemaker( rule_configs.loss_not_decreasing(), 
                                                     rule_parameters={ "collection_names": "metrics", "num_steps": str(save_interval * 2), }, ), ],
)
xgboost_debugger.set_hyperparameters(
    eta=.35,
    gamma=0.5,
    #lambda_bias=0.4,
    num_round=252                     # required parameter!
    #objective = 'reg:linear',
    )
# Out:
# Parameter image_name will be renamed to image_uri in SageMaker Python SDK v2.

# %% [markdown]
# ## Fit Model

# %%
xgboost_debugger.fit({"train": s3_input_train, "validation": s3_input_valid}, wait=True)
# Out:
# 2020-11-19 18:48:34 Starting - Starting the training job...
# 2020-11-19 18:48:57 Starting - Launching requested ML instances
# ********* Debugger Rule Status *********
# *
# *  LossNotDecreasing: InProgress
# *
# ****************************************
# ......
# 2020-11-19 18:50:00 Starting - Preparing the instances for training......
# 2020-11-19 18:50:59 Downloading - Downloading input data
# 2020-11-19 18:50:59 Training - Downloading the training image...
# 2020-11-19 18:51:19 Training - Training image download completed. Training in progress.INFO:sagemaker-containers:Imported framework sagemaker_xgboost_container.training
# INFO:sagemaker-containers:No GPUs detected (normal if no gpus installed)
# INFO:sagemaker_xgboost_container.training:Running XGBoost Sagemaker in algorithm mode
# INFO:root:Determined delimiter of CSV input is ','
# INFO:root:Determined delimiter of CSV input is ','
# INFO:root:Determined delimiter of CSV input is ','
# [18:51:17] 804602x44 matrix with 35402488 entries loaded from /opt/ml/input/data/train?format=csv&label_column=0&delimiter=,
# INFO:root:Determined delimiter of CSV input is ','
# [18:51:17] 89652x44 matrix with 3944688 entries loaded from /opt/ml/input/data/validation?format=csv&label_column=0&delimiter=,
# INFO:root:Single node training.
# [2020-11-19 18:51:17.801 ip-10-0-89-251.eu-central-1.compute.internal:1 INFO json_config.py:90] Creating hook from json_config at /opt/ml/input/config/debughookconfig.json.
# [2020-11-19 18:51:17.802 ip-10-0-89-251.eu-central-1.compute.internal:1 INFO hook.py:151] tensorboard_dir has not been set for the hook. SMDebug will not be exporting tensorboard summaries.
# [2020-11-19 18:51:17.802 ip-10-0-89-251.eu-central-1.compute.internal:1 INFO hook.py:196] Saving to /opt/ml/output/tensors
# INFO:root:Debug hook created from config
# INFO:root:Train matrix has 804602 rows
# INFO:root:Validation matrix has 89652 rows
# [18:51:17] WARNING: /workspace/src/learner.cc:328:
# Parameters: { num_round } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [0]#011train-rmse:4.35367#011validation-rmse:4.34703
# [2020-11-19 18:51:18.401 ip-10-0-89-251.eu-central-1.compute.internal:1 INFO hook.py:325] Monitoring the collections: losses, metrics, feature_importance
# [1]#011train-rmse:2.98033#011validation-rmse:2.97442
# [2]#011train-rmse:2.14878#011validation-rmse:2.14300
# [3]#011train-rmse:1.67359#011validation-rmse:1.66768
# [4]#011train-rmse:1.42488#011validation-rmse:1.41914
# [5]#011train-rmse:1.30094#011validation-rmse:1.29549
# [6]#011train-rmse:1.24226#011validation-rmse:1.23677
# [7]#011train-rmse:1.21693#011validation-rmse:1.21166
# [8]#011train-rmse:1.20220#011validation-rmse:1.19716
# [9]#011train-rmse:1.19621#011validation-rmse:1.19150
# [10]#011train-rmse:1.19232#011validation-rmse:1.18784
# [11]#011train-rmse:1.18986#011validation-rmse:1.18559
# [12]#011train-rmse:1.18769#011validation-rmse:1.18361
# [13]#011train-rmse:1.18617#011validation-rmse:1.18208
# [14]#011train-rmse:1.18462#011validation-rmse:1.18064
# [15]#011train-rmse:1.18302#011validation-rmse:1.17891
# [16]#011train-rmse:1.18013#011validation-rmse:1.17623
# [17]#011train-rmse:1.17878#011validation-rmse:1.17518
# [18]#011train-rmse:1.17789#011validation-rmse:1.17444
# [19]#011train-rmse:1.17675#011validation-rmse:1.17322
# [20]#011train-rmse:1.17531#011validation-rmse:1.17177
# [21]#011train-rmse:1.17349#011validation-rmse:1.17007
# [22]#011train-rmse:1.17161#011validation-rmse:1.16823
# [23]#011train-rmse:1.17048#011validation-rmse:1.16708
# [24]#011train-rmse:1.17001#011validation-rmse:1.16668
# [25]#011train-rmse:1.16937#011validation-rmse:1.16612
# [26]#011train-rmse:1.16821#011validation-rmse:1.16494
# [27]#011train-rmse:1.16768#011validation-rmse:1.16444
# [28]#011train-rmse:1.16683#011validation-rmse:1.16364
# [29]#011train-rmse:1.16607#011validation-rmse:1.16294
# [30]#011train-rmse:1.16468#011validation-rmse:1.16178
# [31]#011train-rmse:1.16396#011validation-rmse:1.16121
# [32]#011train-rmse:1.16224#011validation-rmse:1.15982
# [33]#011train-rmse:1.16163#011validation-rmse:1.15931
# [34]#011train-rmse:1.16143#011validation-rmse:1.15918
# [35]#011train-rmse:1.16063#011validation-rmse:1.15829
# [36]#011train-rmse:1.15996#011validation-rmse:1.15772
# [37]#011train-rmse:1.15954#011validation-rmse:1.15737
# [38]#011train-rmse:1.15920#011validation-rmse:1.15714
# [39]#011train-rmse:1.15857#011validation-rmse:1.15659
# [40]#011train-rmse:1.15804#011validation-rmse:1.15611
# [41]#011train-rmse:1.15753#011validation-rmse:1.15569
# [42]#011train-rmse:1.15690#011validation-rmse:1.15513
# [43]#011train-rmse:1.15684#011validation-rmse:1.15509
# [44]#011train-rmse:1.15589#011validation-rmse:1.15427
# [45]#011train-rmse:1.15521#011validation-rmse:1.15369
# [46]#011train-rmse:1.15483#011validation-rmse:1.15341
# [47]#011train-rmse:1.15454#011validation-rmse:1.15317
# [48]#011train-rmse:1.15380#011validation-rmse:1.15239
# [49]#011train-rmse:1.15334#011validation-rmse:1.15189
# [50]#011train-rmse:1.15316#011validation-rmse:1.15179
# [51]#011train-rmse:1.15261#011validation-rmse:1.15140
# [52]#011train-rmse:1.15162#011validation-rmse:1.15048
# [53]#011train-rmse:1.15097#011validation-rmse:1.14997
# [54]#011train-rmse:1.15072#011validation-rmse:1.14988
# [55]#011train-rmse:1.15053#011validation-rmse:1.14972
# [56]#011train-rmse:1.14956#011validation-rmse:1.14887
# [57]#011train-rmse:1.14918#011validation-rmse:1.14866
# [58]#011train-rmse:1.14891#011validation-rmse:1.14844
# [59]#011train-rmse:1.14886#011validation-rmse:1.14843
# [60]#011train-rmse:1.14829#011validation-rmse:1.14792
# [61]#011train-rmse:1.14792#011validation-rmse:1.14763
# [62]#011train-rmse:1.14743#011validation-rmse:1.14720
# [63]#011train-rmse:1.14728#011validation-rmse:1.14708
# [64]#011train-rmse:1.14704#011validation-rmse:1.14688
# [65]#011train-rmse:1.14645#011validation-rmse:1.14650
# [66]#011train-rmse:1.14600#011validation-rmse:1.14611
# [67]#011train-rmse:1.14533#011validation-rmse:1.14547
# [68]#011train-rmse:1.14507#011validation-rmse:1.14522
# [69]#011train-rmse:1.14480#011validation-rmse:1.14504
# [70]#011train-rmse:1.14447#011validation-rmse:1.14478
# [71]#011train-rmse:1.14403#011validation-rmse:1.14448
# [72]#011train-rmse:1.14364#011validation-rmse:1.14428
# [73]#011train-rmse:1.14265#011validation-rmse:1.14355
# [74]#011train-rmse:1.14249#011validation-rmse:1.14346
# [75]#011train-rmse:1.14217#011validation-rmse:1.14316
# [76]#011train-rmse:1.14207#011validation-rmse:1.14307
# [77]#011train-rmse:1.14187#011validation-rmse:1.14291
# [78]#011train-rmse:1.14125#011validation-rmse:1.14258
# [79]#011train-rmse:1.14095#011validation-rmse:1.14237
# [80]#011train-rmse:1.14052#011validation-rmse:1.14206
# [81]#011train-rmse:1.14013#011validation-rmse:1.14174
# [82]#011train-rmse:1.13975#011validation-rmse:1.14141
# [83]#011train-rmse:1.13904#011validation-rmse:1.14062
# [84]#011train-rmse:1.13888#011validation-rmse:1.14056
# [85]#011train-rmse:1.13834#011validation-rmse:1.14020
# [86]#011train-rmse:1.13800#011validation-rmse:1.13988
# [87]#011train-rmse:1.13748#011validation-rmse:1.13955
# [88]#011train-rmse:1.13718#011validation-rmse:1.13930
# [89]#011train-rmse:1.13706#011validation-rmse:1.13922
# [90]#011train-rmse:1.13680#011validation-rmse:1.13897
# [91]#011train-rmse:1.13650#011validation-rmse:1.13868
# [92]#011train-rmse:1.13631#011validation-rmse:1.13860
# [93]#011train-rmse:1.13629#011validation-rmse:1.13859
# [94]#011train-rmse:1.13618#011validation-rmse:1.13851
# [95]#011train-rmse:1.13583#011validation-rmse:1.13812
# [96]#011train-rmse:1.13556#011validation-rmse:1.13802
# [97]#011train-rmse:1.13520#011validation-rmse:1.13777
# [98]#011train-rmse:1.13489#011validation-rmse:1.13753
# [99]#011train-rmse:1.13454#011validation-rmse:1.13727
# [100]#011train-rmse:1.13436#011validation-rmse:1.13721
# [101]#011train-rmse:1.13390#011validation-rmse:1.13682
# [102]#011train-rmse:1.13359#011validation-rmse:1.13671
# [103]#011train-rmse:1.13348#011validation-rmse:1.13663
# [104]#011train-rmse:1.13344#011validation-rmse:1.13663
# [105]#011train-rmse:1.13324#011validation-rmse:1.13645
# [106]#011train-rmse:1.13297#011validation-rmse:1.13623
# [107]#011train-rmse:1.13277#011validation-rmse:1.13608
# [108]#011train-rmse:1.13270#011validation-rmse:1.13606
# [109]#011train-rmse:1.13236#011validation-rmse:1.13577
# [110]#011train-rmse:1.13227#011validation-rmse:1.13572
# [111]#011train-rmse:1.13223#011validation-rmse:1.13570
# [112]#011train-rmse:1.13222#011validation-rmse:1.13570
# [113]#011train-rmse:1.13218#011validation-rmse:1.13569
# [114]#011train-rmse:1.13195#011validation-rmse:1.13555
# [115]#011train-rmse:1.13174#011validation-rmse:1.13548
# [116]#011train-rmse:1.13145#011validation-rmse:1.13535
# [117]#011train-rmse:1.13127#011validation-rmse:1.13522
# [118]#011train-rmse:1.13083#011validation-rmse:1.13482
# [119]#011train-rmse:1.13057#011validation-rmse:1.13455
# [120]#011train-rmse:1.13042#011validation-rmse:1.13440
# [121]#011train-rmse:1.13014#011validation-rmse:1.13421
# [122]#011train-rmse:1.13000#011validation-rmse:1.13414
# [123]#011train-rmse:1.12966#011validation-rmse:1.13391
# [124]#011train-rmse:1.12933#011validation-rmse:1.13365
# [125]#011train-rmse:1.12922#011validation-rmse:1.13358
# [126]#011train-rmse:1.12870#011validation-rmse:1.13316
# [127]#011train-rmse:1.12826#011validation-rmse:1.13276
# [128]#011train-rmse:1.12805#011validation-rmse:1.13257
# [129]#011train-rmse:1.12781#011validation-rmse:1.13241
# [130]#011train-rmse:1.12754#011validation-rmse:1.13221
# [131]#011train-rmse:1.12751#011validation-rmse:1.13219
# [132]#011train-rmse:1.12696#011validation-rmse:1.13163
# [133]#011train-rmse:1.12670#011validation-rmse:1.13145
# [134]#011train-rmse:1.12639#011validation-rmse:1.13122
# [135]#011train-rmse:1.12626#011validation-rmse:1.13114
# [136]#011train-rmse:1.12615#011validation-rmse:1.13105
# [137]#011train-rmse:1.12597#011validation-rmse:1.13095
# [138]#011train-rmse:1.12582#011validation-rmse:1.13089
# [139]#011train-rmse:1.12569#011validation-rmse:1.13083
# [140]#011train-rmse:1.12556#011validation-rmse:1.13074
# [141]#011train-rmse:1.12520#011validation-rmse:1.13045
# [142]#011train-rmse:1.12508#011validation-rmse:1.13043
# [143]#011train-rmse:1.12470#011validation-rmse:1.13011
# [144]#011train-rmse:1.12465#011validation-rmse:1.13009
# [145]#011train-rmse:1.12446#011validation-rmse:1.12997
# [146]#011train-rmse:1.12434#011validation-rmse:1.12989
# [147]#011train-rmse:1.12408#011validation-rmse:1.12970
# [148]#011train-rmse:1.12403#011validation-rmse:1.12970
# [149]#011train-rmse:1.12383#011validation-rmse:1.12960
# [150]#011train-rmse:1.12379#011validation-rmse:1.12961
# [151]#011train-rmse:1.12363#011validation-rmse:1.12953
# [152]#011train-rmse:1.12354#011validation-rmse:1.12945
# [153]#011train-rmse:1.12334#011validation-rmse:1.12937
# [154]#011train-rmse:1.12329#011validation-rmse:1.12939
# [155]#011train-rmse:1.12321#011validation-rmse:1.12935
# [156]#011train-rmse:1.12293#011validation-rmse:1.12916
# [157]#011train-rmse:1.12282#011validation-rmse:1.12910
# [158]#011train-rmse:1.12258#011validation-rmse:1.12897
# [159]#011train-rmse:1.12245#011validation-rmse:1.12898
# [160]#011train-rmse:1.12243#011validation-rmse:1.12897
# [161]#011train-rmse:1.12231#011validation-rmse:1.12887
# [162]#011train-rmse:1.12221#011validation-rmse:1.12882
# [163]#011train-rmse:1.12210#011validation-rmse:1.12865
# [164]#011train-rmse:1.12181#011validation-rmse:1.12831
# [165]#011train-rmse:1.12169#011validation-rmse:1.12823
# [166]#011train-rmse:1.12138#011validation-rmse:1.12797
# [167]#011train-rmse:1.12115#011validation-rmse:1.12781
# [168]#011train-rmse:1.12079#011validation-rmse:1.12753
# [169]#011train-rmse:1.12055#011validation-rmse:1.12734
# [170]#011train-rmse:1.11999#011validation-rmse:1.12681
# [171]#011train-rmse:1.11980#011validation-rmse:1.12668
# [172]#011train-rmse:1.11962#011validation-rmse:1.12656
# [173]#011train-rmse:1.11943#011validation-rmse:1.12643
# [174]#011train-rmse:1.11930#011validation-rmse:1.12635
# [175]#011train-rmse:1.11901#011validation-rmse:1.12626
# [176]#011train-rmse:1.11885#011validation-rmse:1.12621
# [177]#011train-rmse:1.11869#011validation-rmse:1.12617
# [178]#011train-rmse:1.11853#011validation-rmse:1.12608
# [179]#011train-rmse:1.11844#011validation-rmse:1.12601
# [180]#011train-rmse:1.11818#011validation-rmse:1.12590
# [181]#011train-rmse:1.11805#011validation-rmse:1.12592
# [182]#011train-rmse:1.11791#011validation-rmse:1.12581
# [183]#011train-rmse:1.11775#011validation-rmse:1.12574
# [184]#011train-rmse:1.11766#011validation-rmse:1.12571
# [185]#011train-rmse:1.11759#011validation-rmse:1.12568
# [186]#011train-rmse:1.11748#011validation-rmse:1.12562
# [187]#011train-rmse:1.11713#011validation-rmse:1.12530
# [188]#011train-rmse:1.11698#011validation-rmse:1.12521
# [189]#011train-rmse:1.11686#011validation-rmse:1.12518
# [190]#011train-rmse:1.11668#011validation-rmse:1.12505
# [191]#011train-rmse:1.11660#011validation-rmse:1.12496
# [192]#011train-rmse:1.11647#011validation-rmse:1.12492
# [193]#011train-rmse:1.11641#011validation-rmse:1.12487
# [194]#011train-rmse:1.11612#011validation-rmse:1.12472
# [195]#011train-rmse:1.11608#011validation-rmse:1.12473
# [196]#011train-rmse:1.11600#011validation-rmse:1.12472
# [197]#011train-rmse:1.11590#011validation-rmse:1.12472
# [198]#011train-rmse:1.11579#011validation-rmse:1.12466
# [199]#011train-rmse:1.11572#011validation-rmse:1.12465
# [200]#011train-rmse:1.11561#011validation-rmse:1.12460
# [201]#011train-rmse:1.11557#011validation-rmse:1.12459
# [202]#011train-rmse:1.11547#011validation-rmse:1.12452
# [203]#011train-rmse:1.11541#011validation-rmse:1.12452
# [204]#011train-rmse:1.11518#011validation-rmse:1.12434
# [205]#011train-rmse:1.11505#011validation-rmse:1.12440
# [206]#011train-rmse:1.11488#011validation-rmse:1.12430
# [207]#011train-rmse:1.11468#011validation-rmse:1.12413
# [208]#011train-rmse:1.11449#011validation-rmse:1.12400
# [209]#011train-rmse:1.11435#011validation-rmse:1.12397
# [210]#011train-rmse:1.11406#011validation-rmse:1.12382
# [211]#011train-rmse:1.11387#011validation-rmse:1.12377
# [212]#011train-rmse:1.11374#011validation-rmse:1.12370
# [213]#011train-rmse:1.11367#011validation-rmse:1.12371
# [214]#011train-rmse:1.11365#011validation-rmse:1.12370
# [215]#011train-rmse:1.11351#011validation-rmse:1.12360
# [216]#011train-rmse:1.11340#011validation-rmse:1.12355
# [217]#011train-rmse:1.11331#011validation-rmse:1.12348
# [218]#011train-rmse:1.11316#011validation-rmse:1.12334
# [219]#011train-rmse:1.11302#011validation-rmse:1.12325
# [220]#011train-rmse:1.11291#011validation-rmse:1.12320
# [221]#011train-rmse:1.11275#011validation-rmse:1.12301
# [222]#011train-rmse:1.11267#011validation-rmse:1.12296
# [223]#011train-rmse:1.11258#011validation-rmse:1.12294
# [224]#011train-rmse:1.11242#011validation-rmse:1.12283
# [225]#011train-rmse:1.11235#011validation-rmse:1.12279
# [226]#011train-rmse:1.11230#011validation-rmse:1.12280
# [227]#011train-rmse:1.11227#011validation-rmse:1.12281
# [228]#011train-rmse:1.11209#011validation-rmse:1.12266
# [229]#011train-rmse:1.11200#011validation-rmse:1.12264
# [230]#011train-rmse:1.11187#011validation-rmse:1.12259
# [231]#011train-rmse:1.11174#011validation-rmse:1.12256
# [232]#011train-rmse:1.11164#011validation-rmse:1.12251
# [233]#011train-rmse:1.11157#011validation-rmse:1.12248
# [234]#011train-rmse:1.11139#011validation-rmse:1.12240
# [235]#011train-rmse:1.11128#011validation-rmse:1.12239
# [236]#011train-rmse:1.11116#011validation-rmse:1.12232
# [237]#011train-rmse:1.11113#011validation-rmse:1.12233
# [238]#011train-rmse:1.11095#011validation-rmse:1.12223
# [239]#011train-rmse:1.11078#011validation-rmse:1.12217
# [240]#011train-rmse:1.11075#011validation-rmse:1.12217
# [241]#011train-rmse:1.11060#011validation-rmse:1.12206
# [242]#011train-rmse:1.11051#011validation-rmse:1.12203
# [243]#011train-rmse:1.11038#011validation-rmse:1.12193
# [244]#011train-rmse:1.11007#011validation-rmse:1.12174
# [245]#011train-rmse:1.10995#011validation-rmse:1.12166
# [246]#011train-rmse:1.10988#011validation-rmse:1.12167
# [247]#011train-rmse:1.10973#011validation-rmse:1.12155
# [248]#011train-rmse:1.10959#011validation-rmse:1.12149
# [249]#011train-rmse:1.10955#011validation-rmse:1.12149
# [250]#011train-rmse:1.10945#011validation-rmse:1.12151
# [251]#011train-rmse:1.10944#011validation-rmse:1.12152
#
# 2020-11-19 18:52:24 Uploading - Uploading generated training model
# 2020-11-19 18:52:24 Completed - Training job completed
# Training seconds: 102
# Billable seconds: 102

# %%
#!pip install smdebug
from smdebug.trials import create_trial
s3_output_path = xgboost_debugger.latest_job_debugger_artifacts_path()
trial = create_trial(s3_output_path)
# Out:
# [2020-11-19 18:30:03.357 ip-172-16-29-248:6712 INFO s3_trial.py:42] Loading trial debug-output at path s3://aida-project/team_remote/output/JPC-xgboost-debug-2020-11-19-17-49-05-568/debug-output

# %%
#trial.tensor_names()

# %%
trial.tensor("feature_importance/cover/f0").values()
# Out:
# [2020-11-19 18:30:07.762 ip-172-16-29-248:6712 INFO trial.py:198] Training has ended, will refresh one final time in 1 sec.
# [2020-11-19 18:30:08.781 ip-172-16-29-248:6712 INFO trial.py:210] Loaded all steps
# {50: array([0.04307063]),
#  100: array([0.03059408]),
#  150: array([0.03497543]),
#  200: array([0.03457847]),
#  250: array([0.03615072])}

# %%
liste = trial.tensor_names()

# %%
#[k for k in lst if 'ab' in k]
feature_importance_names = [k for k in liste if 'feature_importance/cover' in k]
feature_importance_col_names = ['isAdult', 'startYear', 'endYear', 'numVotes', 'Crime', 'Romance', 'Thriller', 'Adventure', 'Drama', 'War', 'Documentary', 'Reality-TV', 'Family', 'Fantasy', 'Game-Show', 'Adult', 'History', 'Mystery', 'Musical', 'Animation', 'Music', 'Film-Noir', 'shortGenre', 'Horror', 'Western', 'Biography', 'Comedy', 'Action', 'Sport', 'Talk-Show', 'Sci-Fi', 'News', 'movie', 'short', 'tvEpisode', 'tvMiniSeries', 'tvMovie', 'tvSeries', 'tvShort', 'tvSpecial', 'video', 'videoGame', 'distinct languages', 'distinct regions']
feature_importance_weight = [k for k in liste if 'feature_importance/weight' in k]

# %%
feat_dict_start={}
feat_dict_ende={}
start=50
ende=250
for i,f in enumerate(feature_importance_names):
    #print(feature_importance_col_names[i],"\t\t",end='')
    #print(trial.tensor(f).values())
    #print(trial.tensor(f).values()[40][0])
    index=int(f.split('f')[2])
    try:
        feat_dict_start[feature_importance_col_names[index]]=trial.tensor(f).values()[start][0]
    except:
        feat_dict_start[feature_importance_col_names[index]]=0
    #break
print(feat_dict_start)
for i,f in enumerate(feature_importance_names):
    index=int(f.split('f')[2])
    try:
        feat_dict_ende[feature_importance_col_names[index]]=trial.tensor(f).values()[ende][0]
    except:
        feat_dict_ende[feature_importance_col_names[index]]=0
print(feat_dict_ende)
# Out:
# {'isAdult': 0.043070633060439546, 'startYear': 0.007380599209238163, 'Documentary': 0.01680715591483466, 'Reality-TV': 0.014729369591736773, 'Family': 0.008675791912772459, 'Fantasy': 0.018864678649165335, 'Game-Show': 0.019857007618346297, 'Adult': 0.0111572589578705, 'History': 0.03569844428840835, 'Mystery': 0.026027873911947212, 'Musical': 0.004243897242865821, 'Animation': 0.010987531128428775, 'endYear': 0.023886251401637394, 'Music': 0.019636491752060985, 'Film-Noir': 0, 'shortGenre': 0.0047985481200190135, 'Horror': 0.023522206981917097, 'Western': 0.045496208101381094, 'Biography': 0.02403963828534207, 'Comedy': 0.005559561293491315, 'Action': 0.005575477818618715, 'Sport': 0.012658318095690086, 'Talk-Show': 0.023573496069841087, 'numVotes': 0.010704162928185374, 'Sci-Fi': 0.0298902649955347, 'News': 0.05429731831675873, 'movie': 0.025938731072778817, 'short': 0.01783569714452138, 'tvEpisode': 0.012901508832324, 'tvMiniSeries': 0.0772715932370043, 'tvMovie': 0.014151690409486344, 'tvSeries': 0.014323628863418262, 'tvShort': 0.07045080751388284, 'tvSpecial': 0.030000880483581932, 'Crime': 0.019302663831728784, 'video': 0.01130773971066375, 'videoGame': 0.05861501909501618, 'distinct languages': 0.014951517522723739, 'distinct regions': 0.01654198625670346, 'Romance': 0.018816013356613624, 'Thriller': 0.023370621568420343, 'Adventure': 0.006967644711648789, 'Drama': 0.010338469797900368, 'War': 0.055775600945051455}
# {'isAdult': 0.03615071738955885, 'startYear': 0.009061087932714108, 'Documentary': 0.013818386861336322, 'Reality-TV': 0.014267271764552388, 'Family': 0.012568105510179239, 'Fantasy': 0.01495516165508641, 'Game-Show': 0.024886395457740965, 'Adult': 0.042982255498708107, 'History': 0.01494314897867138, 'Mystery': 0.01578936909514141, 'Musical': 0.019085831961888795, 'Animation': 0.010490269720920771, 'endYear': 0.024504525986946163, 'Music': 0.015327685583355975, 'Film-Noir': 0.143796277731414, 'shortGenre': 0.010384203667117323, 'Horror': 0.018837593538186228, 'Western': 0.07506663119999447, 'Biography': 0.01869077350592242, 'Comedy': 0.007560006466803765, 'Action': 0.010043958571044478, 'Sport': 0.016291925566533406, 'Talk-Show': 0.02011764572755798, 'numVotes': 0.016666201313618845, 'Sci-Fi': 0.02714688209187644, 'News': 0.03259787763502257, 'movie': 0.01413794060564555, 'short': 0.01914350810746696, 'tvEpisode': 0.010016717509741735, 'tvMiniSeries': 0.02691917212544828, 'tvMovie': 0.018755940331699958, 'tvSeries': 0.018034915552970366, 'tvShort': 0.033253274874104115, 'tvSpecial': 0.026517991386420782, 'Crime': 0.012444118085096443, 'video': 0.013998122855863299, 'videoGame': 0.03813777238125003, 'distinct languages': 0.01689122146295635, 'distinct regions': 0.015664705294065807, 'Romance': 0.012887029887270253, 'Thriller': 0.01642136888050694, 'Adventure': 0.010080088677573693, 'Drama': 0.007900631270614756, 'War': 0.02276529029941189}

# %%
feat_weight_dict={}
for i,f in enumerate(feature_importance_weight):
    index=int(f.split('f')[2])
    print(feature_importance_col_names[index],"\t\t",end='')
    print("i,f:",str(i)," ", f)
    print(trial.tensor(f).values())
    #print(trial.tensor(f).values()[40][0])
    feat_weight_dict[feature_importance_col_names[index]]=trial.tensor(f).values()[ende][0]
    #break
#print(feat_weight_dict)
# Out:
# isAdult 		i,f: 0   feature_importance/weight/f0
# {50: array([0.00292778]), 100: array([0.00424809]), 150: array([0.00398997]), 200: array([0.00360021]), 250: array([0.00393266])}
# startYear 		i,f: 1   feature_importance/weight/f1
# {0: array([0.23728814]), 50: array([0.18867925]), 100: array([0.18249788]), 150: array([0.18661651]), 200: array([0.184982]), 250: array([0.18469712])}
# Documentary 		i,f: 2   feature_importance/weight/f10
# {0: array([0.05084746]), 50: array([0.017892]), 100: array([0.01699235]), 150: array([0.01641587]), 200: array([0.01645808]), 250: array([0.01573065])}
# Reality-TV 		i,f: 3   feature_importance/weight/f11
# {0: array([0.05084746]), 50: array([0.01724138]), 100: array([0.01614274]), 150: array([0.01561788]), 200: array([0.01585805]), 250: array([0.01566165])}
# Family 		i,f: 4   feature_importance/weight/f12
# {50: array([0.0214704]), 100: array([0.02090059]), 150: array([0.01972184]), 200: array([0.01980113]), 250: array([0.01952532])}
# Fantasy 		i,f: 5   feature_importance/weight/f13
# {50: array([0.01203643]), 100: array([0.0115548]), 150: array([0.0120839]), 200: array([0.01200069]), 250: array([0.011591])}
# Game-Show 		i,f: 6   feature_importance/weight/f14
# {0: array([0.01694915]), 50: array([0.00910865]), 100: array([0.0086661]), 150: array([0.00911993]), 200: array([0.00840048]), 250: array([0.00834828])}
# Adult 		i,f: 7   feature_importance/weight/f15
# {50: array([0.0035784]), 100: array([0.00407816]), 150: array([0.00398997]), 200: array([0.00342877]), 250: array([0.0034497])}
# History 		i,f: 8   feature_importance/weight/f16
# {50: array([0.00487964]), 100: array([0.00526763]), 150: array([0.00604195]), 200: array([0.0062575]), 250: array([0.00683041])}
# Mystery 		i,f: 9   feature_importance/weight/f17
# {50: array([0.00975927]), 100: array([0.00968564]), 150: array([0.00911993]), 200: array([0.00925767]), 250: array([0.00938319])}
# Musical 		i,f: 10   feature_importance/weight/f18
# {50: array([0.00553025]), 100: array([0.00679694]), 150: array([0.00581395]), 200: array([0.00505743]), 250: array([0.00538154])}
# Animation 		i,f: 11   feature_importance/weight/f19
# {0: array([0.01694915]), 50: array([0.02667534]), 100: array([0.02276975]), 150: array([0.02200182]), 200: array([0.02177267]), 250: array([0.01987029])}
# endYear 		i,f: 12   feature_importance/weight/f2
# {0: array([0.01694915]), 50: array([0.03838647]), 100: array([0.04706882]), 150: array([0.0494756]), 200: array([0.05083148]), 250: array([0.05153857])}
# Music 		i,f: 13   feature_importance/weight/f20
# {50: array([0.01463891]), 100: array([0.01852167]), 150: array([0.01675787]), 200: array([0.01628664]), 250: array([0.01545467])}
# Film-Noir 		i,f: 14   feature_importance/weight/f21
# {100: array([0.00016992]), 150: array([0.000114]), 200: array([8.5719184e-05]), 250: array([6.89940665e-05])}
# shortGenre 		i,f: 15   feature_importance/weight/f22
# {50: array([0.01203643]), 100: array([0.01257434]), 150: array([0.01185591]), 200: array([0.01242928]), 250: array([0.01228094])}
# Horror 		i,f: 16   feature_importance/weight/f23
# {0: array([0.08474576]), 50: array([0.02212101]), 100: array([0.01937128]), 150: array([0.01664387]), 200: array([0.01551517]), 250: array([0.01490272])}
# Western 		i,f: 17   feature_importance/weight/f24
# {50: array([0.00325309]), 100: array([0.00356839]), 150: array([0.00307798]), 200: array([0.00274301]), 250: array([0.00269077])}
# Biography 		i,f: 18   feature_importance/weight/f25
# {0: array([0.01694915]), 50: array([0.00650618]), 100: array([0.00679694]), 150: array([0.00638395]), 200: array([0.00634322]), 250: array([0.00641645])}
# Comedy 		i,f: 19   feature_importance/weight/f26
# {50: array([0.03285621]), 100: array([0.03568394]), 150: array([0.03647971]), 200: array([0.03540202]), 250: array([0.03360011])}
# Action 		i,f: 20   feature_importance/weight/f27
# {50: array([0.01886792]), 100: array([0.01954121]), 150: array([0.01903785]), 200: array([0.01945825]), 250: array([0.01966331])}
# Sport 		i,f: 21   feature_importance/weight/f28
# {50: array([0.01268705]), 100: array([0.01087511]), 150: array([0.01003192]), 200: array([0.00960055]), 250: array([0.0092452])}
# Talk-Show 		i,f: 22   feature_importance/weight/f29
# {0: array([0.01694915]), 50: array([0.01008458]), 100: array([0.01036534]), 150: array([0.01071591]), 200: array([0.01037202]), 250: array([0.01014213])}
# numVotes 		i,f: 23   feature_importance/weight/f3
# {0: array([0.23728814]), 50: array([0.1906311]), 100: array([0.19813084]), 150: array([0.20519836]), 200: array([0.21155495]), 250: array([0.21836622])}
# Sci-Fi 		i,f: 24   feature_importance/weight/f30
# {50: array([0.00975927]), 100: array([0.01019541]), 150: array([0.00911993]), 200: array([0.00908623]), 250: array([0.00910722])}
# News 		i,f: 25   feature_importance/weight/f31
# {0: array([0.01694915]), 50: array([0.00553025]), 100: array([0.00492778]), 150: array([0.00547196]), 200: array([0.00548603]), 250: array([0.00538154])}
# movie 		i,f: 26   feature_importance/weight/f32
# {0: array([0.01694915]), 50: array([0.0143136]), 100: array([0.01393373]), 150: array([0.0128819]), 200: array([0.01260072]), 250: array([0.01297088])}
# short 		i,f: 27   feature_importance/weight/f33
# {50: array([0.00943396]), 100: array([0.01002549]), 150: array([0.00923393]), 200: array([0.00857192]), 250: array([0.00869325])}
# tvEpisode 		i,f: 28   feature_importance/weight/f34
# {0: array([0.01694915]), 50: array([0.02342225]), 100: array([0.02463891]), 150: array([0.02359781]), 200: array([0.02211555]), 250: array([0.02042224])}
# tvMiniSeries 		i,f: 29   feature_importance/weight/f35
# {50: array([0.00292778]), 100: array([0.00220901]), 150: array([0.00182399]), 200: array([0.0022287]), 250: array([0.00262177])}
# tvMovie 		i,f: 30   feature_importance/weight/f36
# {0: array([0.01694915]), 50: array([0.01496422]), 100: array([0.01104503]), 150: array([0.00991792]), 200: array([0.00917195]), 250: array([0.00890023])}
# tvSeries 		i,f: 31   feature_importance/weight/f37
# {50: array([0.01561483]), 100: array([0.01376381]), 150: array([0.01356589]), 200: array([0.01311504]), 250: array([0.01228094])}
# tvShort 		i,f: 32   feature_importance/weight/f38
# {50: array([0.00065062]), 100: array([0.00067969]), 150: array([0.00136799]), 200: array([0.0018001]), 250: array([0.00186284])}
# tvSpecial 		i,f: 33   feature_importance/weight/f39
# {50: array([0.00618087]), 100: array([0.00543755]), 150: array([0.00535796]), 200: array([0.00522887]), 250: array([0.00489858])}
# Crime 		i,f: 34   feature_importance/weight/f4
# {50: array([0.01138582]), 100: array([0.01359388]), 150: array([0.01390789]), 200: array([0.0151723]), 250: array([0.01552366])}
# video 		i,f: 35   feature_importance/weight/f40
# {0: array([0.01694915]), 50: array([0.01496422]), 100: array([0.01325404]), 150: array([0.01333789]), 200: array([0.01380079]), 250: array([0.01297088])}
# videoGame 		i,f: 36   feature_importance/weight/f41
# {50: array([0.00390371]), 100: array([0.00305862]), 150: array([0.00296398]), 200: array([0.00308589]), 250: array([0.00324272])}
# distinct languages 		i,f: 37   feature_importance/weight/f42
# {0: array([0.06779661]), 50: array([0.03448276]), 100: array([0.03194562]), 150: array([0.03305974]), 200: array([0.03334476]), 250: array([0.03318615])}
# distinct regions 		i,f: 38   feature_importance/weight/f43
# {0: array([0.06779661]), 50: array([0.06929083]), 100: array([0.06542056]), 150: array([0.06646147]), 200: array([0.06540374]), 250: array([0.06588933])}
# Romance 		i,f: 39   feature_importance/weight/f5
# {50: array([0.01561483]), 100: array([0.01563297]), 150: array([0.01538988]), 200: array([0.01757243]), 250: array([0.01793846])}
# Thriller 		i,f: 40   feature_importance/weight/f6
# {50: array([0.00910865]), 100: array([0.01172472]), 150: array([0.01037392]), 200: array([0.01020058]), 250: array([0.01069408])}
# Adventure 		i,f: 41   feature_importance/weight/f7
# {50: array([0.02212101]), 100: array([0.02124044]), 150: array([0.02029184]), 200: array([0.01954397]), 250: array([0.01876639])}
# Drama 		i,f: 42   feature_importance/weight/f8
# {0: array([0.03389831]), 50: array([0.03155498]), 100: array([0.03211555]), 150: array([0.03248974]), 200: array([0.03154466]), 250: array([0.03153029])}
# War 		i,f: 43   feature_importance/weight/f9
# {50: array([0.00292778]), 100: array([0.0028887]), 150: array([0.00307798]), 200: array([0.00342877]), 250: array([0.00434663])}

# %%
import matplotlib.pyplot as plt
plt.bar(range(len(feat_dict_start)),list(feat_dict_start.values()))
plt.title(f"Feature_importances (after {start} training steps)", fontsize=20)
plt.show()
plt.bar(range(len(feat_dict_ende)),list(feat_dict_ende.values()))
plt.title(f"Feature_importances (after {ende} training steps)", fontsize=20)
# Out:
# Text(0.5, 1.0, 'Feature_importances (after 250 training steps)')

# %%
plt.bar(range(len(feat_weight_dict)),list(feat_weight_dict.values()))
plt.title("Feature_importances_weight", fontsize=20)
# Out:
# Text(0.5, 1.0, 'Feature_importances_weight')

# %%
import pandas as pd

# %%
from datetime import datetime

now = datetime.now() # current date and time
time = now.strftime("%m-%d-%Y-%H-%M-%S")
#print(time)

dict = feat_dict_ende

fig,ax = plt.subplots(figsize=(20,10))

#pd.DataFrame(feat_dict, index=['quantity']).plot(kind='bar',ax=ax,use_index=False, legend=False,width=1.4)
plt.bar(*zip(*dict.items()))
plt.title(f'Feature Importances ({ende} runs)', fontsize=20)
plt.xlabel('Feature', fontsize=20)
plt.ylabel('share', fontsize=20)
plt.xticks(ticks=[])
threshold=0.038
pad=0.001
i=0
for k,v in dict.items():
    if v > threshold:
        ax.text(i,v+pad,k.replace(" ","\n"),horizontalalignment='center',fontsize=20)
    #reak
    i +=1
#plt.xlim([0,10])
#plt.ylim([0,10])
#plt.plot([0,10],[0,10], c='red')

#plt.show()
save_it=True
if save_it == True:
    filename='Feature_importance_1-'+time
    plt.savefig(filename, dpi=None, facecolor='w', edgecolor='w',
        orientation='portrait')
plt.show()

# %%
sum=0
for k,v in feat_dict_ende.items():
    sum=sum+v
print(round(sum,7))
# Out:
# 1.0

# %% [markdown]
# # Deploy Model

# %% [markdown]
# ## Deploy

# %%
# Deploy  model to an endpoint

xgb_predictor = xgboost_debugger.deploy(
    initial_instance_count = 1, 
    instance_type = 'ml.t2.medium')
# Out:
# Parameter image will be renamed to image_uri in SageMaker Python SDK v2.
# -----------------!

# %% [markdown]
# ## Configure Predictor

# %%
# Configure the predictor's serializer and deserializer

# INSERT CODE HERE

from sagemaker.predictor import csv_serializer, json_deserializer

xgb_predictor.content_type = "text/csv"
xgb_predictor.serializer = csv_serializer
xgb_predictor.deserializer = json_deserializer

# %% [markdown]
# # Display Endpoint

# %%
xgb_predictor.endpoint
# Out:
# 'JPC-xgboost-debug-2020-11-19-16-46-57-820'

# %% [markdown]
# # Prediction

# %%
# carefully just one prediction
import pandas as pd
import matplotlib.pyplot as plt

#col_names = ['averageRating', 'isAdult', 'startYear', 'endYear', 'numVotes', 'Crime', 'Romance', 'Thriller', 'Adventure', 'Drama', 'War', 'Documentary', 'Reality-TV', 'Family', 'Fantasy', 'Game-Show', 'Adult', 'History', 'Mystery', 'Musical', 'Animation', 'Music', 'Film-Noir', 'shortGenre', 'Horror', 'Western', 'Biography', 'Comedy', 'Action', 'Sport', 'Talk-Show', 'Sci-Fi', 'News', 'movie', 'short', 'tvEpisode', 'tvMiniSeries', 'tvMovie', 'tvSeries', 'tvShort', 'tvSpecial', 'video', 'videoGame', 'distinct languages', 'distinct regions']
test = pd.read_csv(f"{s3_path}{test_source_path}/{test_source_name}", header=0, index_col=False, names=feature_importance_col_names)
prediction=[]
for i in range(test.shape[0]):
    prediction.append(xgb_predictor.predict(test.iloc[i, 1:]))
    if i % 5000 == 0:
        print(i)
    #     print(prediction)
    #     print(test.iloc[i,0])
#print(prediction) 

#plt.scatter(test.iloc[:,0], prediction)
# Out:
# 0
# 5000
# 10000
# 15000
# 20000
# 25000
# 30000
# 35000
# 40000
# 45000
# 50000
# 55000
# 60000
# 65000
# 70000
# 75000
# 80000
# 85000
# 90000
# 95000

# %%
from datetime import datetime

now = datetime.now() # current date and time
time = now.strftime("%m-%d-%Y-%H-%M-%S")
print(time)



fig = plt.subplots(figsize=(10,10))
plt.scatter(test.iloc[:,0], prediction,marker='.',alpha=0.3)
plt.title(f'Third Prediction (train data) {ende} steps', fontsize=20)
plt.xlabel('original value')
plt.ylabel('predicted value')
plt.xlim([0,10])
plt.ylim([0,10])
plt.plot([0,10],[0,10], c='red')

#plt.show()
filename='Prediction-'+time
plt.savefig(filename, dpi=None, facecolor='w', edgecolor='w',
        orientation='portrait')
# Out:
# 11-19-2020-17-27-42

# %%
# Out:
# 11-18-2020-14-55-10
